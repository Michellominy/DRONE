# %% [markdown]
# # UART COMMUNICATION WITH GPS

# %%
from pynq.overlays.base import BaseOverlay

base = BaseOverlay("base.bit")
base.select_rpi()

# %%
# %%microblaze base.RPI
#
# #include "uart.h"
# #include "pyprintf.h"
# #include "xio_switch.h"
#
# #define UART_TXD 14
# #define UART_RXD 15
#
#
# int gps_main(unsigned char* buffer, int buffer_size) {
#     //pyprintf("INNNNNNNNNN\n");
#     float lat, lon;
#     uart gps_uart = uart_open(UART_TXD, UART_RXD);
#
#     if (gps_uart == -1){
#         pyprintf("ERROR UART DID NOT OPEN\n");
#         return -1;
#     }
#
#     //unsigned char buffer[256];  // Buffer to store UART data
#
#     while (1) {
#         //pyprintf("READING...\n");
#         uart_read(gps_uart, buffer, buffer_size);
#         //pyprintf("%s\n", buffer);
#         return 1;
#         /*if (parse_gpgga(buffer, &lat, &lon)) {
#             printf("GPS data: lat=%.6f, lon=%.6f\n", lat, lon);
#             return;
#         }*/
#     }
# }

# %%
from pynq import allocate
import numpy as np
import time

while(True):
    buffer_size = 50
    buffer = allocate(shape=(buffer_size,), dtype=np.uint8)

    gps_main(buffer, buffer_size)
    

    
    if chr(buffer[0]) == '$':
        print(f"{buffer}")
        data = ''.join(chr(elem) for elem in buffer if elem != 0)
        print("data: " + data)
    
    buffer.freebuffer()
    #time.sleep(0.1)

# %%
from pynq.overlays.base import BaseOverlay
from pynq.lib import MicroblazeLibrary
base = BaseOverlay ('base.bit') 
print ('finish')

lib = MicroblazeLibrary(base.RPI, ['uart']) 
device = lib.uart_open(14,15)

import time
changeBaudRate_command = [0xB5, 0x62, 0x06, 0x08, 0x00, 0x00, 0x0E, 0x30, 
0xB5, 0x62, 0x06, 0x08, 0x06, 0x00, 0x64, 0x00,
0x01, 0x00, 0x01, 0x00, 0x7A, 0x12, 0xB5, 0x62, 
0x06, 0x08, 0x00, 0x00, 0x0E, 0x30]
#poll_config = [ 0xB5, 0x62,0x06, 0x00,  0x01, 0x00, 0x00, 0x08, 0x22]
print("writing...")
device.write(changeBaudRate_command, len(changeBaudRate_command))

buffer_size = 1
while True:
    buf = bytearray(buffer_size)
    device.read(buf, buffer_size)
    print(buf)

# %%
from pynq.overlays.base import BaseOverlay
from pynq.lib import MicroblazeLibrary
from time import sleep

base = BaseOverlay ('base.bit') 
print ('finish')

lib = MicroblazeLibrary(base.ARDUINO, ['uart']) 
device = lib.uart_open(1,0) # TX, RX
# device = lib.uart_open(14,15) # TX, RX

buffer_size = 50
buf = bytearray(buffer_size)

# Initialize variables for accumulating data
accumulated_data = ""
in_sentence = False

while True:
    # Read data from the UART device
    device.read(buf, buffer_size)
    #print(buf)
    # Decode the bytearray to string
    data = buf.decode('ascii')
    
    # Iterate over each character in the decoded data
    for char in data:
        if char == '$':
            # Start of a new sentence
            if in_sentence:
                # Print the accumulated sentence
                print(accumulated_data)
            # Start accumulating a new sentence
            accumulated_data = char
            in_sentence = True
        elif char == '\r' or char == '\n':
            # End of a sentence
            if in_sentence:
                # Print the accumulated sentence and reset
                print(accumulated_data)
                accumulated_data = ""
                in_sentence = False
        else:
            # Continue accumulating data
            if in_sentence:
                accumulated_data += char
    
    # Sleep to avoid overwhelming the UART buffer
    sleep(0.5)

# %% [markdown]
# # I2C Communication with COMPASS

# %%
from pynq.overlays.base import BaseOverlay
from pynq.lib import MicroblazeLibrary
from pynq import Overlay

base = BaseOverlay("base.bit")
# lib = MicroblazeLibrary(base.RPI, ['i2c'])
lib = MicroblazeLibrary(base.PMODA, ['i2c'])

# %%
from time import sleep

COMPASS_DEVICE_ADDRESS = 0x1E
CRA = 0x00
CRB = 0x01
MODE = 0x02
COMPASS_DRX = 0x03
COMPASS_DRZ = 0x05
COMPASS_DRY = 0x07

## Pmod I2C Pin Definitions
PMOD_SDA_PIN = 6  ## or 2
PMOD_SCL_PIN = 7  ## or 3
RPI_SDA_PIN = 3
RPI_SCL_PIN = 5

# i2c_device = lib.i2c_open(RPI_SDA_PIN, RPI_SCL_PIN)
i2c_device = lib.i2c_open(PMOD_SDA_PIN, PMOD_SCL_PIN)

def iic_writeByte(devAddr, regAddr, data):
    temp = bytearray(2)
    temp[0] = regAddr
    temp[1] = data
    i2c_device.write(devAddr, temp, 2)
    
def iic_readByte(devAddr, regAddr):
    temp = bytearray(1)
    temp[0] = regAddr
    i2c_device.write(devAddr, temp, 1)
    i2c_device.read(devAddr, temp, 1)    
    return temp[0]

def iic_readBytes(devAddr, regAddr, length):
    temp = bytearray(length)
    temp[0] = regAddr
    i2c_device.write(devAddr, temp, 1)
    i2c_device.read(devAddr, temp, length)    
    return temp

def COMPASS_read(addr):
    high = iic_readByte(COMPASS_DEVICE_ADDRESS, addr)
    low = iic_readByte(COMPASS_DEVICE_ADDRESS, addr+1)
    
    return ((high[0] << 8) | low[1])

def COMPASS_INIT():
    data = 0x70
    iic_writeByte(COMPASS_DEVICE_ADDRESS, CRA, data)
    data = 0xA0
    iic_writeByte(COMPASS_DEVICE_ADDRESS, CRB, data)
    data = 0x00
    iic_writeByte(COMPASS_DEVICE_ADDRESS, MODE, data)
    sleep(10e-3)

COMPASS_INIT()    
while True:
    x = COMPASS_read(COMPASS_DRX)
    z = COMPASS_read(COMPASS_DRZ)
    y = COMPASS_read(COMPASS_DRY)
    
    print("Magnetometer data: x=%d, y=%d, z=%d" % (x, y, z))    
    sleep(1)

i2c_device.close()
# Out:
# ---------------------------------------------------------------------------
# MicroblazeError                           Traceback (most recent call last)
# Input In [32], in <cell line: 55>()
#      52     iic_writeByte(COMPASS_DEVICE_ADDRESS, MODE, data)
#      53     sleep(10e-3)
# ---> 55 COMPASS_INIT()
#      56 while True:
#      57     x = COMPASS_read(COMPASS_DRX)
#
# Input In [32], in COMPASS_INIT()
#      46 def COMPASS_INIT():
#      47     data = 0x70
# ---> 48     iic_writeByte(COMPASS_DEVICE_ADDRESS, CRA, data)
#      49     data = 0xA0
#      50     iic_writeByte(COMPASS_DEVICE_ADDRESS, CRB, data)
#
# Input In [32], in iic_writeByte(devAddr, regAddr, data)
#      22 temp[0] = regAddr
#      23 temp[1] = data
# ---> 24 i2c_device.write(devAddr, temp, 2)
#
# File <string>:3, in wrapped(self, slave_address, buffer, length)
#
# ...

# %% [markdown]
# # I2C Communication with GYRO/ACCEL

# %%
from pynq.overlays.base import BaseOverlay
from pynq.lib import MicroblazeLibrary
from pynq import Overlay

base = BaseOverlay("base.bit")
# lib = MicroblazeLibrary(base.RPI, ['i2c'])
lib = MicroblazeLibrary(base.PMODB, ['i2c'])

# %%
from time import sleep

#  !!!! MPU MUST be supplied with 5V because of the onboard 3.3v regulator !!!!
MPU_DEVICE_ADDRESS = 0x68
MPU_PWR_MGMT_1   = 0x6B
MPU_SMPLRT_DIV   = 0x19
MPU_CONFIG       = 0x1A
MPU_GYRO_CONFIG  = 0x1B
MPU_INT_ENABLE   = 0x38
MPU_ACCEL_XOUT_H = 0x3B
MPU_ACCEL_YOUT_H = 0x3D
MPU_ACCEL_ZOUT_H = 0x3F
MPU_GYRO_XOUT_H  = 0x43
MPU_GYRO_YOUT_H  = 0x45
MPU_GYRO_ZOUT_H  = 0x47
MPU_SIGNAL_PATH_RESET = 0x68

## Pmod I2C Pin Definitions
PMOD_SDA_PIN = 6  ## or 2
PMOD_SCL_PIN = 7  ## or 3
RPI_SDA_PIN = 3
RPI_SCL_PIN = 5

# i2c_device = lib.i2c_open(RPI_SDA_PIN, RPI_SCL_PIN)
i2c_device = lib.i2c_open(PMOD_SDA_PIN, PMOD_SCL_PIN)
print(f"HANDLE: ${i2c_device}")
def iic_writeByte(devAddr, regAddr, data):
    temp = bytearray(2)
    temp[0] = regAddr
    temp[1] = data
    i2c_device.write(devAddr, temp, 2)
    
    
def iic_readByte(devAddr, regAddr):
    temp = bytearray(1)
    temp[0] = regAddr
    i2c_device.write(devAddr, temp, 1)
    i2c_device.read(devAddr, temp, 1)    
    return temp[0]

    
# https://www.electronicwings.com/raspberry-pi/mpu6050-accelerometergyroscope-interfacing-with-raspberry-pi
def MPU_Init():    
    iic_writeByte(MPU_DEVICE_ADDRESS, MPU_SMPLRT_DIV, 7)
    sleep(100e-3)
    iic_writeByte(MPU_DEVICE_ADDRESS, MPU_PWR_MGMT_1, 1)
    sleep(100e-3)
    iic_writeByte(MPU_DEVICE_ADDRESS, MPU_CONFIG, 0)
    sleep(100e-3)
    iic_writeByte(MPU_DEVICE_ADDRESS, MPU_GYRO_CONFIG, 24)
    sleep(100e-3)
    iic_writeByte(MPU_DEVICE_ADDRESS, MPU_INT_ENABLE, 1)
    sleep(100e-3)
    


def MPU_read(addr):
    #Accelero and Gyro value are 16-bit
    high = iic_readByte(MPU_DEVICE_ADDRESS, addr)
    low = iic_readByte(MPU_DEVICE_ADDRESS, addr+1)

    #concatenate higher and lower value
    value = ((high << 8) | low)

    #to get signed value from mpu6050
    if(value > 32768):
            value = value - 65536
    return value


MPU_Init()
while True:
    #Read Accelerometer raw value
    acc_x = MPU_read(MPU_ACCEL_XOUT_H)
    acc_y = MPU_read(MPU_ACCEL_YOUT_H)
    acc_z = MPU_read(MPU_ACCEL_ZOUT_H)

    #Read Gyroscope raw value
    gyro_x = MPU_read(MPU_GYRO_XOUT_H)
    gyro_y = MPU_read(MPU_GYRO_YOUT_H)
    gyro_z = MPU_read(MPU_GYRO_ZOUT_H)

    #Full scale range +/- 250 degree/C as per sensitivity scale factor
    Ax = acc_x/16384.0
    Ay = acc_y/16384.0
    Az = acc_z/16384.0

    Gx = gyro_x/131.0
    Gy = gyro_y/131.0
    Gz = gyro_z/131.0

    print ("Gx=%.2f" %Gx, u'\u00b0'+ "/s", "\tGy=%.2f" %Gy, u'\u00b0'+ "/s", "\tGz=%.2f" %Gz, u'\u00b0'+ "/s", "\tAx=%.2f g" %Ax, "\tAy=%.2f g" %Ay, "\tAz=%.2f g" %Az) 	
    sleep(1)

i2c_device.close()

# %% [markdown]
# # I2C Communication TCA

# %%
from pynq.overlays.base import BaseOverlay
from pynq.lib import MicroblazeLibrary
from pynq import Overlay

base = BaseOverlay("base.bit")
# lib = MicroblazeLibrary(base.RPI, ['i2c'])
lib = MicroblazeLibrary(base.PMODB, ['i2c'])

# %%
from time import sleep

# TCA9548A
TCA_DEVICE_ADDRESS = 0x70

#  !!!! MPU MUST be supplied with 5V because of the onboard 3.3v regulator !!!!
MPU_DEVICE_ADDRESS = 0x68
MPU_PWR_MGMT_1   = 0x6B
MPU_SMPLRT_DIV   = 0x19
MPU_CONFIG       = 0x1A
MPU_GYRO_CONFIG  = 0x1B
MPU_INT_ENABLE   = 0x38
MPU_ACCEL_XOUT_H = 0x3B
MPU_ACCEL_YOUT_H = 0x3D
MPU_ACCEL_ZOUT_H = 0x3F
MPU_GYRO_XOUT_H  = 0x43
MPU_GYRO_YOUT_H  = 0x45
MPU_GYRO_ZOUT_H  = 0x47
MPU_SIGNAL_PATH_RESET = 0x68


## Pmod I2C Pin Definitions
PMOD_SDA_PIN = 6  ## or 2
PMOD_SCL_PIN = 7  ## or 3
# RPI_SDA_PIN = 3
# RPI_SCL_PIN = 5

# i2c_device = lib.i2c_open(RPI_SDA_PIN, RPI_SCL_PIN)
i2c_device = lib.i2c_open(PMOD_SDA_PIN, PMOD_SCL_PIN)

def iic_writeByte(devAddr, regAddr, data):
    temp = bytearray(2)
    temp[0] = regAddr
    temp[1] = data
    i2c_device.write(devAddr, temp, 2)
    
    
def iic_readByte(devAddr, regAddr):
    temp = bytearray(1)
    temp[0] = regAddr
    i2c_device.write(devAddr, temp, 1)
    i2c_device.read(devAddr, temp, 1)    
    return temp[0]


def TCA_channel_select(channel):
    """Select an individual channel."""
    if channel > 7:
        return
    iic_writeByte(TCA_DEVICE_ADDRESS, 0x00, 1 << channel) # TODO: what is the regAddr ??

    
    
# https://www.electronicwings.com/raspberry-pi/mpu6050-accelerometergyroscope-interfacing-with-raspberry-pi
def MPU_Init():    
    iic_writeByte(MPU_DEVICE_ADDRESS, MPU_SMPLRT_DIV, 7)
    sleep(100e-3)
    iic_writeByte(MPU_DEVICE_ADDRESS, MPU_PWR_MGMT_1, 1)
    sleep(100e-3)
    iic_writeByte(MPU_DEVICE_ADDRESS, MPU_CONFIG, 0)
    sleep(100e-3)
    iic_writeByte(MPU_DEVICE_ADDRESS, MPU_GYRO_CONFIG, 24)
    sleep(100e-3)
    iic_writeByte(MPU_DEVICE_ADDRESS, MPU_INT_ENABLE, 1)
    sleep(100e-3)
    


def MPU_read(addr):
    #Accelero and Gyro value are 16-bit
    high = iic_readByte(MPU_DEVICE_ADDRESS, addr)
    low = iic_readByte(MPU_DEVICE_ADDRESS, addr+1)

    #concatenate higher and lower value
    value = ((high << 8) | low)

    #to get signed value from mpu6050
    if(value > 32768):
            value = value - 65536
    return value

    
TCA_channel_select(1)
MPU_Init()
while True:
    #Read Accelerometer raw value
    acc_x = MPU_read(MPU_ACCEL_XOUT_H)
    acc_y = MPU_read(MPU_ACCEL_YOUT_H)
    acc_z = MPU_read(MPU_ACCEL_ZOUT_H)

    #Read Gyroscope raw value
    gyro_x = MPU_read(MPU_GYRO_XOUT_H)
    gyro_y = MPU_read(MPU_GYRO_YOUT_H)
    gyro_z = MPU_read(MPU_GYRO_ZOUT_H)

    #Full scale range +/- 250 degree/C as per sensitivity scale factor
    Ax = acc_x/16384.0
    Ay = acc_y/16384.0
    Az = acc_z/16384.0

    Gx = gyro_x/131.0
    Gy = gyro_y/131.0
    Gz = gyro_z/131.0

    print ("Gx=%.2f" %Gx, u'\u00b0'+ "/s", "\tGy=%.2f" %Gy, u'\u00b0'+ "/s", "\tGz=%.2f" %Gz, u'\u00b0'+ "/s", "\tAx=%.2f g" %Ax, "\tAy=%.2f g" %Ay, "\tAz=%.2f g" %Az) 	
    sleep(1)

i2c_device.close()
# Out:
# Gx=-0.34 °/s 	Gy=-0.30 °/s 	Gz=0.24 °/s 	Ax=0.01 g 	Ay=-0.02 g 	Az=-0.97 g
# Gx=-0.34 °/s 	Gy=-0.31 °/s 	Gz=0.25 °/s 	Ax=0.01 g 	Ay=0.01 g 	Az=-1.00 g
# Gx=-0.34 °/s 	Gy=-0.29 °/s 	Gz=0.24 °/s 	Ax=0.01 g 	Ay=0.01 g 	Az=-0.99 g
# Gx=-0.34 °/s 	Gy=-0.31 °/s 	Gz=0.24 °/s 	Ax=0.01 g 	Ay=-0.01 g 	Az=-0.99 g
# Gx=-0.34 °/s 	Gy=-0.31 °/s 	Gz=0.26 °/s 	Ax=0.01 g 	Ay=0.02 g 	Az=-0.97 g
# Gx=-0.34 °/s 	Gy=-0.31 °/s 	Gz=0.24 °/s 	Ax=0.01 g 	Ay=0.00 g 	Az=-0.99 g
# Gx=-0.32 °/s 	Gy=-0.33 °/s 	Gz=0.24 °/s 	Ax=0.01 g 	Ay=0.00 g 	Az=-1.00 g
# Gx=-0.34 °/s 	Gy=-0.28 °/s 	Gz=0.25 °/s 	Ax=0.01 g 	Ay=0.00 g 	Az=-0.98 g
# Gx=-0.34 °/s 	Gy=-0.31 °/s 	Gz=0.24 °/s 	Ax=0.01 g 	Ay=-0.00 g 	Az=-0.99 g
# Gx=-2.81 °/s 	Gy=0.31 °/s 	Gz=0.44 °/s 	Ax=0.01 g 	Ay=0.02 g 	Az=-1.09 g
# Gx=-0.69 °/s 	Gy=-0.37 °/s 	Gz=0.35 °/s 	Ax=0.02 g 	Ay=0.15 g 	Az=-0.98 g
# Gx=-0.21 °/s 	Gy=-0.09 °/s 	Gz=0.25 °/s 	Ax=-0.08 g 	Ay=0.02 g 	Az=-0.96 g
# Gx=-0.34 °/s 	Gy=-0.31 °/s 	Gz=0.25 °/s 	Ax=0.01 g 	Ay=-0.01 g 	Az=-1.00 g
# ...

# %% [markdown]
# # MOTOR COMMUNICATION

# %%
from pynq.overlays.base import BaseOverlay
from pynq.lib import MicroblazeLibrary
from pynq import Overlay

base = BaseOverlay("base.bit")
# lib = MicroblazeLibrary(base.RPI, ['i2c'])
lib = MicroblazeLibrary(base.PMODB, ['i2c'])
# Out:
# KeyboardInterrupt

# %%
from time import sleep
import math

# TCA9548A
TCA_DEVICE_ADDRESS = 0x70


## Pmod I2C Pin Definitions
PMOD_SDA_PIN = 6  ## or 2
PMOD_SCL_PIN = 7  ## or 3
# RPI_SDA_PIN = 3
# RPI_SCL_PIN = 5


# PCA9685
PCA9685_ADDRESS = 0x40
PCA9685_MODE1 = 0x00
PCA9685_MODE2 = 0x01
SUBADR1 = 0x02
SUBADR2 = 0x03
SUBADR3 = 0x04
PCA9685_PRESCALE = 0xFE
LED0_ON_L = 0x06
LED0_ON_H = 0x07
LED0_OFF_L = 0x08
LED0_OFF_H = 0x09

# Bits:
PCA9685_RESTART = 0x80
PCA9685_SLEEP = 0x10
PCA9685_EXTCLK = 0x40
PCA9685_ALLCALL = 0x01
PCA9685_INVRT = 0x10
PCA9685_OUTDRV = 0x04


# i2c_device = lib.i2c_open(RPI_SDA_PIN, RPI_SCL_PIN)
i2c_device = lib.i2c_open(PMOD_SDA_PIN, PMOD_SCL_PIN)

def iic_writeByte(devAddr, regAddr, data):
    temp = bytearray(2)
    temp[0] = regAddr
    temp[1] = data
    i2c_device.write(devAddr, temp, 2)
    
    
def iic_readByte(devAddr, regAddr):
    temp = bytearray(1)
    temp[0] = regAddr
    i2c_device.write(devAddr, temp, 1)
    i2c_device.read(devAddr, temp, 1)    
    return temp[0]


def TCA_channel_select(channel):
    """Select an individual channel."""
    if channel > 7:
        return
    iic_writeByte(TCA_DEVICE_ADDRESS, 0x00, 1 << channel)
    sleep(1)

# https://github.com/adafruit/Adafruit_Python_PCA9685/blob/master/Adafruit_PCA9685/PCA9685.py
def PCA_Init():    
    iic_writeByte(PCA9685_ADDRESS, PCA9685_MODE2, PCA9685_OUTDRV)
    iic_writeByte(PCA9685_ADDRESS, PCA9685_MODE1, PCA9685_ALLCALL)
    sleep(0.005)
    mode1 = iic_readByte(PCA9685_ADDRESS, PCA9685_MODE1)
    mode1 = mode1 & ~PCA9685_SLEEP 
    iic_writeByte(PCA9685_ADDRESS, PCA9685_MODE1, mode1)
    sleep(0.005)
    
    set_pwm_freq(1000)


def set_pwm_freq(freq_hz):
    prescaleval = 25000000.0    # 25MHz
    prescaleval /= 4096.0       # 12-bit
    prescaleval /= float(freq_hz)
    prescaleval -= 1.0
    prescale = int(math.floor(prescaleval + 0.5))
    oldmode = iic_readByte(PCA9685_ADDRESS, PCA9685_MODE1)
    newmode = (oldmode & 0x7F) | 0x10    # sleep
    iic_writeByte(PCA9685_ADDRESS, PCA9685_MODE1, newmode)  # go to sleep
    iic_writeByte(PCA9685_ADDRESS, PCA9685_PRESCALE, prescale)
    iic_writeByte(PCA9685_ADDRESS, PCA9685_MODE1, oldmode)
    sleep(0.005)
    iic_writeByte(PCA9685_ADDRESS, PCA9685_MODE1, oldmode | 0x80)
    
    

def set_pwm(channel, on, off):
    """Sets a single PWM channel."""
    iic_writeByte(PCA9685_ADDRESS, LED0_ON_L+4*channel, on & 0xFF)
    iic_writeByte(PCA9685_ADDRESS, LED0_ON_H+4*channel, on >> 8)
    iic_writeByte(PCA9685_ADDRESS, LED0_OFF_L+4*channel, off & 0xFF)
    iic_writeByte(PCA9685_ADDRESS, LED0_OFF_H+4*channel, off >> 8)

    
def arm_motors():
    channels = [3, 4, 7, 8]
    
     # Convert microseconds to PWM range used by PCA9685
    def us_to_pwm(value_us):
        return int(value_us * 4096 / 20000)  # 20ms period
    
    min_pwm = us_to_pwm(1000)
    max_pwm = us_to_pwm(2000)

    
    for channel in channels:
        sleep(0.5)
        set_pwm(channel, 0, min_pwm)
        sleep(1)
        set_pwm(channel, 0, max_pwm)
        sleep(1)
        set_pwm(channel, 0, min_pwm)
        sleep(0.5)
        
    print("ARMING SEQUENCE DONE")

print("TCA SELECT CHANNEL 0")
TCA_channel_select(0)

print("INITIALIZE PWM DRIVER")
PCA_Init()

# PCA9685 12 bit PWM resolution ==> max value = 4096
# ESC: Available throttle calibration range is from 1000us to 2000us

# i2c_device.close()

# %%
print("STARTING ARMING SEQUENCE")
arm_motors()
# Out:
# STARTING ARMING SEQUENCE
# ARMING SEQUENCE DONE

# %%
def start_motors(speed_us=1000):
    """
    Start the motors with the specified speed.
    
    Parameters:
    speed_us (int): Desired pulse width in microseconds for motor speed (typically between 1100µs and 1900µs).
    """
    channels = [3, 4, 7, 8]
    # Convert microseconds to PWM range used by PCA9685
    def us_to_pwm(value_us):
        return int(value_us * 4096 / 20000)  # 20ms period
    
    speed_pwm = us_to_pwm(speed_us)
    
    for channel in channels:
        set_pwm(channel, 0, speed_pwm)
    
    print("MOTORS STARTED WITH SPEED PWM VALUE: ", speed_pwm)

def start_motor(speed_us, channel):
    
    # Convert microseconds to PWM range used by PCA9685
    def us_to_pwm(value_us):
        return int(value_us * 4096 / 20000)  # 20ms period
    
    speed_pwm = us_to_pwm(speed_us)
    
    set_pwm(channel, 0, speed_pwm)
    
    print("MOTORS STARTED WITH SPEED PWM VALUE: ", speed_pwm)

    
# start_motor(1500)

# %%
start_motor(1300, 3) # front rigth
start_motor(1300, 7) # front left
start_motor(1280, 4) # rear right
start_motor(1280, 8) # rear left
# Out:
# MOTORS STARTED WITH SPEED PWM VALUE:  266
# MOTORS STARTED WITH SPEED PWM VALUE:  266
# MOTORS STARTED WITH SPEED PWM VALUE:  262
# MOTORS STARTED WITH SPEED PWM VALUE:  262

# %%
start_motors(0)
# Out:
# MOTORS STARTED WITH SPEED PWM VALUE:  0

# %% [markdown]
# # TEST C/C++ MicroBlaze

# %%
from pynq.overlays.base import BaseOverlay
from pynq.lib import MicroblazeLibrary

base = BaseOverlay("base.bit")
# lib = MicroblazeLibrary(base.PMODB, ['i2c']) # NOT NEEDED ???
# dir(base)
# dir(base.PMODA)
print(base)
print(base.PMODA)
print(base.PMODB)
print(base.PMODB.values)
# Out:
# ...
# {'ip_name': 'iop_pmoda/mb_bram_ctrl', 'rst_name': 'mb_iop_pmoda_reset', 'intr_pin_name': 'iop_pmoda/dff_en_reset_vector_0/q', 'intr_ack_name': 'mb_iop_pmoda_intr_ack', 'mbtype': 'Pmod', 'name': 'iop_pmoda'}
# {'ip_name': 'iop_pmodb/mb_bram_ctrl', 'rst_name': 'mb_iop_pmodb_reset', 'intr_pin_name': 'iop_pmodb/dff_en_reset_vector_0/q', 'intr_ack_name': 'mb_iop_pmodb_intr_ack', 'mbtype': 'Pmod', 'name': 'iop_pmodb'}
# <built-in method values of dict object at 0xacf62578>

# %%
# %%microblaze base.PMODB
#
# # include <stdint.h>
# # include <string.h>
# #include "xio_switch.h"
# #include "xparameters.h"
#
# /* PYNQ MicroBlaze headers  */
# #include <i2c.h>
# #include <pyprintf.h>
#
#
# #define MB_CLOCK_FREQ_HZ 100000000
#
# #define TMR_BASEADDR XPAR_TMRCTR_0_BASEADDR
# #define TMR_TCSR1 (*(volatile uint32_t *)(TMR_BASEADDR + 0x10))
# #define TMR_TLR1 (*(volatile uint32_t *)(TMR_BASEADDR + 0x14))
# #define TMR_TCR1 (*(volatile uint32_t *)(TMR_BASEADDR + 0x18))
# #define TMR_CSR_LOAD_MASK 0x00000020 // Load Timer (set bit 5)
# #define TMR_CSR_ARHT_MASK 0x00000010 // Auto-Reload (set bit 4)
# #define TMR_CSR_ENT_MASK 0x00000080  // Enable Timer (set bit 7)
# #define TMR_CSR_GENT_MASK 0x00000004 // Generate Event (set bit 2)
# #define TMR_CSR_UDT_MASK 0x00000002  // Up/Down Timer (set bit 1)
#
#
#
# /* Mailbox addresses  */
# #define MAILBOX_BASE        0xF000
# #define MAILBOX_CMD_ADDR    (*(volatile unsigned int *)(0xFFFC))
# #define MAILBOX_DATA(i)     (*(volatile unsigned int *)(MAILBOX_BASE + ((i)*4)))
#
# /* Commands */
# #define CMD_NOP             0x0
# #define CMD_START_PID       0x1
# #define CMD_STOP_PID        0x2
# #define CMD_SET_GAINS       0x3
# #define CMD_SET_SETPOINTS   0x4
# #define CMD_HEARTBEAT       0x5
# #define CMD_GET_LOG         0x6
#
# /* Logging */
# #define LOG_BASE_ADDRESS    (MAILBOX_BASE + 16)
# #define LOG_ITEM_SIZE       sizeof(uint32_t)
# #define LOG_CAPACITY        (4000 / LOG_ITEM_SIZE)
#
# /* Constants from constant.py */
# #define TCA_DEVICE_ADDRESS      0x70
# #define TCA_MOTOR_CHANNEL       0
# #define TCA_MPU_CHANNEL         1
#
# #define MPU_DEVICE_ADDRESS      0x68
# #define MPU_PWR_MGMT_1          0x6B
# #define MPU_SMPLRT_DIV          0x19
# #define MPU_CONFIG              0x1A
# #define MPU_GYRO_CONFIG         0x1B
# #define MPU_INT_ENABLE          0x38
# #define MPU_ACCEL_XOUT_H        0x3B
# #define MPU_ACCEL_YOUT_H        0x3D
# #define MPU_ACCEL_ZOUT_H        0x3F
# #define MPU_GYRO_XOUT_H         0x43
# #define MPU_GYRO_YOUT_H         0x45
# #define MPU_GYRO_ZOUT_H         0x47
#
# #define PCA9685_ADDRESS         0x40
# #define PCA9685_MODE1           0x00
# #define PCA9685_MODE2           0x01
# #define PCA9685_PRESCALE        0xFE
# #define LED0_ON_L               0x06
# #define LED0_ON_H               0x07
# #define LED0_OFF_L              0x08
# #define LED0_OFF_H              0x09
# #define PCA9685_SLEEP           0x10
# #define PCA9685_ALLCALL         0x01
# #define PCA9685_OUTDRV          0x04
# #define PCA9685_AI              0x20  // Auto-Increment Bit (Bit 5 of MODE1)
#
# #define PMOD_TCA_SDA_PIN 6
# #define PMOD_TCA_SCL_PIN 7
# // PMOD B (Motors) - "PIN 2,3" on second PMOD corresponds to global indices 10 and 11
# // In Pynq Dual PMOD overlay: D10/D11 support SCL1/SDA1.
# #define PMOD_MOTOR_SDA_PIN 10
# #define PMOD_MOTOR_SCL_PIN 11
#
#
# /* Motor microsecond range */
# #define MIN_MOTOR_US 1000
# #define MAX_MOTOR_US 2000
#
# /* Q16.16 helpers */
# typedef int32_t q16;
# #define Q16_ONE (1<<16)
# static inline q16 float_to_q16(float f)  { return (q16)(f * (float)Q16_ONE); }
# static inline float q16_to_float(q16 q)  { return ((float)q) / (float)Q16_ONE; }
# static inline q16 q16_mul(q16 a, q16 b)  { return (q16)(((int64_t)a * (int64_t)b) >> 16); }
# static inline q16 q16_div(q16 a, q16 b)  { return (q16)((((int64_t)a << 16) / (int64_t)b)); }
#
#
# /* PID struct */
# typedef struct {
#     q16 kp, ki, kd;
#     q16 integ;
#     q16 last_err;
#     q16 out_min, out_max;
# } pid_type;
#
# /* Globals */
# volatile uint32_t *log_ptr = (volatile uint32_t*)LOG_BASE_ADDRESS;
# uint32_t log_index = 0;
#
# i2c i2c_tca;
# i2c i2c_motor;
#
# pid_type pid_roll, pid_pitch, pid_yaw;
#
# void mb_i2c_open(void);
# int i2c_write_reg(uint8_t dev_addr, uint8_t reg, const uint8_t *data, int len);
# int i2c_read_reg(uint8_t dev_addr, uint8_t reg, uint8_t *buf, int len);
#
# void tca_select_channel(uint8_t channel);
#
# void pca_write8(uint8_t reg, uint8_t value);
# uint8_t pca_read8(uint8_t reg);
# void pca9685_init(void);
# void pca9685_set_pwm(int motor, uint16_t on, uint16_t off);
# uint16_t us_to_pca_value(int us);
# void pca9685_set_pwm_us(int motor, int us);
#
# void mpu_init(void);
# int16_t mpu_read_raw16(uint8_t reg);
# void mpu_read_gyro(q16 *gx, q16 *gy, q16 *gz);
#
# void mb_write_motor_pwm_from_q16(int motor, q16 norm_q16, int min_us, int max_us);
# q16 pid_step(pid_type *p, q16 setpoint, q16 measurement, q16 dt_q16);
# void mb_delay_ms(uint32_t ms);
#
# void timer_init_ms()
# {
#     TMR_TLR1 = 0;
#     TMR_TCSR1 = TMR_CSR_LOAD_MASK;
#     TMR_TCSR1 = TMR_CSR_ENT_MASK | TMR_CSR_ARHT_MASK | TMR_CSR_GENT_MASK ;
# }
#
# uint32_t get_timer_ms(void)
# {
#     uint32_t current_count = TMR_TCR1;
#     uint32_t elapsed_ms = (uint32_t)((uint64_t)current_count * 1000 / MB_CLOCK_FREQ_HZ);
#     return elapsed_ms;
# }
#
# /*
# void mb_i2c_open(void) {
#     init_io_switch();
#     set_pin(PMOD_TCA_SCL_PIN, SCL0);
#     set_pin(PMOD_TCA_SDA_PIN, SDA0);
#     mb_delay_ms(10);
#     i2c_tca = i2c_open(PMOD_TCA_SDA_PIN, PMOD_TCA_SCL_PIN);
#     uint8_t mask = (1 << TCA_MPU_CHANNEL);
#     i2c_write(i2c_tca, TCA_DEVICE_ADDRESS, &mask, 1);
# }*/
#
# void mb_i2c_open(void)
# {
#     init_io_switch();
#
#     set_pin(PMOD_TCA_SCL_PIN, SCL0);
#     set_pin(PMOD_TCA_SDA_PIN, SDA0);
#
#     set_pin(PMOD_MOTOR_SCL_PIN, SCL1);
#     set_pin(PMOD_MOTOR_SDA_PIN, SDA1);
#
#     // Open both I2C devices
#     i2c_tca = i2c_open(PMOD_TCA_SDA_PIN, PMOD_TCA_SCL_PIN);
#     i2c_motor = i2c_open(PMOD_MOTOR_SDA_PIN, PMOD_MOTOR_SCL_PIN);
#
#     uint8_t mask = (1 << TCA_MPU_CHANNEL); // NOT NEEDED ?!?!?!?!
#     i2c_write(i2c_tca, TCA_DEVICE_ADDRESS, &mask, 1); // NOT NEEDED ?!?!?!?!
# }
#
#
# int i2c_tca_write_reg(uint8_t dev_addr, uint8_t reg, const uint8_t *data, int len) {
#     unsigned char buf[32];
#     if (len + 1 > (int)sizeof(buf)) return -1;
#     buf[0] = reg;
#     memcpy(&buf[1], data, len);
#     return i2c_write(i2c_tca, dev_addr, buf, len + 1);
# }
#
# int i2c_tca_read_reg(uint8_t dev_addr, uint8_t reg, uint8_t *buf, int len) {
#     uint8_t tx = reg;
#     i2c_write(i2c_tca, dev_addr, (unsigned char*)&tx, 1);
#     return i2c_read(i2c_tca, dev_addr, (unsigned char*)buf, len);
# }
#
# int i2c_motor_write_reg(uint8_t dev_addr, uint8_t reg, const uint8_t *data, int len)
# {
#     unsigned char buf[32];
#     if (len + 1 > (int)sizeof(buf))
#         return -1;
#     buf[0] = reg;
#     memcpy(&buf[1], data, len);
#
#     return i2c_write(i2c_motor, dev_addr, buf, len + 1);
# }
#
# int i2c_motor_read_reg(uint8_t dev_addr, uint8_t reg, uint8_t *buf, int len)
# {
#     uint8_t tx = reg;
#     i2c_write(i2c_motor, dev_addr, (unsigned char *)&tx, 1);
#     return i2c_read(i2c_motor, dev_addr, (unsigned char *)buf, len);
# }
#
# void tca_select_channel(uint8_t channel) {
#     if (channel > 7) return;
#     uint8_t mask = (uint8_t)(1 << channel);
#     // TCA9548A is NOT register-based. It expects a single byte (the mask) written
#     // to its address to select the channel. Use i2c_write directly.
#     i2c_write(i2c_tca, TCA_DEVICE_ADDRESS, &mask, 1);
# }
#
#
# void pca9685_set_pwm(int motor, uint16_t on, uint16_t off)
# {
#     int ch;
#     switch (motor)
#     {
#     case 1: ch = 3; break;
#     case 2: ch = 4; break;
#     case 3: ch = 7; break;
#     case 4: ch = 8; break;
#     default: return;
#     }
#
#     uint8_t ON_L = LED0_ON_L + 4 * ch;
#
#     // Create a buffer with all 4 bytes
#     uint8_t payload[4];
#     payload[0] = on & 0xFF;
#     payload[1] = (on >> 8) & 0x0F;
#     payload[2] = off & 0xFF;
#     payload[3] = (off >> 8) & 0x0F;
#
#     // Write all 4 bytes in ONE transaction
#     // i2c_write_reg automatically sends the Register address (ON_L)
#     // followed by the 4 bytes of data. The PCA9685 auto-increments the
#     // internal pointer to ON_H, OFF_L, OFF_H automatically.
#     i2c_motor_write_reg(PCA9685_ADDRESS, ON_L, payload, 4);
# }
#
#
#
# /* convert microseconds to 12-bit PCA value */
# uint16_t us_to_pca_value(int us) {
#     uint32_t v = ((uint32_t)us * 4096U) / 20000U; /* int math of us * 4096 / 20000 */
#     if (v > 4095U) v = 4095U;
#     return (uint16_t)v;
# }
# void pca9685_set_pwm_us(int motor, int us) {
#     uint16_t val = us_to_pca_value(us);
#     pca9685_set_pwm(motor, 0, val);
# }
#
#
# void pca_write8(uint8_t reg, uint8_t value) {
#     i2c_motor_write_reg(PCA9685_ADDRESS, reg, &value, 1);
# }
#
# uint8_t pca_read8(uint8_t reg) {
#     uint8_t v = 0;
#     i2c_motor_read_reg(PCA9685_ADDRESS, reg, &v, 1);
#     return v;
# }
# void pca9685_init(void)
# {
#     pca_write8(PCA9685_MODE1, PCA9685_OUTDRV);
#     pyprintf("1\n");
#     pca_write8(PCA9685_MODE1, PCA9685_ALLCALL);
#     mb_delay_ms(5);
#     pyprintf("2\n");
#     uint8_t mode1 = pca_read8(PCA9685_MODE1);
#     mode1 &= ~PCA9685_SLEEP; // Wake up
#     pyprintf("3\n");
#     pca_write8(PCA9685_MODE1, mode1);
#     mb_delay_ms(5);
#     pyprintf("4\n");
#
#     // Set Prescale
#     float freq = 1000.0f;
#     float prescaleval = 25000000.0f / (4096.0f * freq) - 1.0f;
#     int prescale = (int)(prescaleval + 0.5f);
#
#     uint8_t oldmode = pca_read8(PCA9685_MODE1);
#     pyprintf("5\n");
#     uint8_t newmode = (oldmode & 0x7F) | 0x10; // Sleep to set prescale
#     pca_write8(PCA9685_MODE1, newmode);
#     pca_write8(PCA9685_PRESCALE, (uint8_t)prescale);
#
#     pca_write8(PCA9685_MODE1, oldmode);
#     mb_delay_ms(5);
#
#     // IMPORTANT: Enable Auto-Increment (PCA9685_AI) here
#     // This sets bit 5 HIGH, allowing us to write sequential registers in one go
#     pca_write8(PCA9685_MODE1, oldmode | 0x80 | PCA9685_AI);
# }
#
# /* MPU init and read */
# void mpu_init(void) {
#     tca_select_channel(TCA_MPU_CHANNEL);
#     uint8_t tmp;
#     tmp = 7; i2c_tca_write_reg(MPU_DEVICE_ADDRESS, MPU_SMPLRT_DIV, &tmp, 1); mb_delay_ms(100);
#     tmp = 1; i2c_tca_write_reg(MPU_DEVICE_ADDRESS, MPU_PWR_MGMT_1, &tmp, 1); mb_delay_ms(100);
#     tmp = 0; i2c_tca_write_reg(MPU_DEVICE_ADDRESS, MPU_CONFIG, &tmp, 1); mb_delay_ms(100);
#     tmp = 24; i2c_tca_write_reg(MPU_DEVICE_ADDRESS, MPU_GYRO_CONFIG, &tmp, 1); mb_delay_ms(100);
#     tmp = 1; i2c_tca_write_reg(MPU_DEVICE_ADDRESS, MPU_INT_ENABLE, &tmp, 1); mb_delay_ms(100);
# }
#
# /* read 16-bit signed big-endian from MPU */
# int16_t mpu_read_raw16(uint8_t reg) {
#     uint8_t buf[2];
#     i2c_tca_read_reg(MPU_DEVICE_ADDRESS, reg, buf, 2);
#     return (int16_t)((buf[0] << 8) | buf[1]);
# }
#
#
# /* read gyro scaled to deg/s and convert to Q16 */
# /*void mpu_read_gyro(q16 *gx, q16 *gy, q16 *gz) {
#     tca_select_channel(TCA_MPU_CHANNEL);
#     int16_t rx = mpu_read_raw16(MPU_GYRO_XOUT_H);
#     int16_t ry = mpu_read_raw16(MPU_GYRO_YOUT_H);
#     int16_t rz = mpu_read_raw16(MPU_GYRO_ZOUT_H);
#     float fx = ((float)rx) / 131.0f;
#     float fy = ((float)ry) / 131.0f;
#     float fz = ((float)rz) / 131.0f;
#     *gx = float_to_q16(fx);
#     *gy = float_to_q16(fy);
#     *gz = float_to_q16(fz);
# }
# */
# void mpu_read_gyro(q16 *gx, q16 *gy, q16 *gz)
# {
#     uint8_t buf[6];
#
#     tca_select_channel(TCA_MPU_CHANNEL);
#
#     int ret = i2c_tca_read_reg(MPU_DEVICE_ADDRESS, MPU_GYRO_XOUT_H, buf, 6);
#
#     int16_t rx = (int16_t)((buf[0] << 8) | buf[1]);
#     int16_t ry = (int16_t)((buf[2] << 8) | buf[3]);
#     int16_t rz = (int16_t)((buf[4] << 8) | buf[5]);
#
#     const int32_t GYRO_SCALE_DIV = 131;
#
#     *gx = float_to_q16((float)rx / GYRO_SCALE_DIV);
#     *gy = float_to_q16(-(float)ry / GYRO_SCALE_DIV);
#     *gz = float_to_q16(-(float)rz / GYRO_SCALE_DIV);
# }
#
#
# /* convert Q16 normalized throttle [0..1] to PCA microseconds and set pwm */
# void mb_write_motor_pwm_from_q16(int motor, q16 norm_q16, int min_us, int max_us) {
#     float f = q16_to_float(norm_q16);
#     if (f < 0.0f) f = 0.0f;
#     if (f > 1.0f) f = 1.0f;
#     int us = (int)(min_us + f * (max_us - min_us));
#     pca9685_set_pwm_us(motor, us);
# }
#
# void arm_motor(int ch){
#     pca9685_set_pwm_us(ch, MIN_MOTOR_US);
#     mb_delay_ms(1000);
#     pca9685_set_pwm_us(ch, MAX_MOTOR_US);
#     mb_delay_ms(1000);
#     pca9685_set_pwm_us(ch, MIN_MOTOR_US);
#     mb_delay_ms(1000);
# }
#
# /*
# void arm_motors(){
#     for(int i = 1; i <= 4; i++){
#         pca9685_set_pwm_us(i, MIN_MOTOR_US);
#         mb_delay_ms(1000);
#         pca9685_set_pwm_us(i, MAX_MOTOR_US);
#         mb_delay_ms(1000);
#         pca9685_set_pwm_us(i, MIN_MOTOR_US);
#         mb_delay_ms(1000);
#     }
#     mb_delay_ms(1000);
#     pyprintf("ARMING SEQUENCE DONE\n");
# }
# */
#
# void arm_all(){
#     for(int i = 1; i <= 4; i++){
#         arm_motor(i);
#     }
#     mb_delay_ms(1000);
#     pyprintf("ARMING SEQUENCE DONE\n");
# }
#
# void motors_init(){
#     pyprintf("Starting Motors init...\n");
#     pca9685_init();
#     pyprintf("PCA init done...\n");
#     arm_all();
# }
#
#
# /* ========================================TEST================================== */
# int test_gyro() {
#     pyprintf("Start\n");
#     timer_init_ms();
#     mb_i2c_open();
#     pyprintf("I2C Open...\n");
#     mpu_init();
#     pyprintf("FINISHED SETUP, READING GYRO...\n");
#
#     tca_select_channel(TCA_MPU_CHANNEL);
#
#     while (1) {
#         pyprintf("=============================\n");
#
#
#         /*int16_t rx = mpu_read_raw16(MPU_GYRO_XOUT_H);
#         int16_t ry = mpu_read_raw16(MPU_GYRO_YOUT_H);
#         int16_t rz = mpu_read_raw16(MPU_GYRO_ZOUT_H);
#
#         float fx = ((float)rx) / 131.0f;
#         float fy = ((float)ry) / 131.0f;
#         float fz = ((float)rz) / 131.0f;*/
#
#
#         q16 gx, gy, gz;
#         mpu_read_gyro(&gx, &gy, &gz);
#         float fx = q16_to_float(gx);
#         float fy = q16_to_float(gy);
#         float fz = q16_to_float(gz);
#
#         pyprintf("fx=%f, fy=%f, fz=%f\n", fx, fy, fz);
#
#         mb_delay_ms(500);
#     }
#
#     return 0;
# }
#
#
# int test_motor_init(){
#     timer_init_ms();
#     mb_i2c_open();
#     motors_init();
#     return 0;
# }
#
#
# int test_motor_start(){
#     tca_select_channel(TCA_MOTOR_CHANNEL);
#     int speed_us = 1050;
#     for(int i = 1; i <= 4; i++){
#         pca9685_set_pwm_us(i, speed_us);
#     }
#     pyprintf("motor started with speed : %d", speed_us);
#     return 0;
# }
#
# int test_motor_stop(){
#     tca_select_channel(TCA_MOTOR_CHANNEL);
#     int speed_us = 0;
#     for(int i = 1; i <= 4; i++){
#         pca9685_set_pwm_us(i, speed_us);
#     }
#     pyprintf("motor stopped with speed : %d", speed_us);
#     return 0;
# }
#
# void mb_delay_ms(uint32_t ms)
# {
#     uint32_t start = get_timer_ms();
#     // Use unsigned 32-bit subtraction, which handles timer rollover correctly
#     while ((get_timer_ms() - start) < ms);
# }
#
#
# int test_timer(){
#     timer_init_ms();
#     for(int i = 0; i<1000; i++){
#         pyprintf("======================LOOP: %d\n", i);
#         uint32_t start_ms = get_timer_ms();
#         mb_delay_ms(100);
#         uint32_t end_ms = get_timer_ms();
#         uint32_t elapsed_ms = end_ms - start_ms;
#         pyprintf("Start : %d\n", (int)start_ms);
#         pyprintf("End : %d\n", (int)end_ms);
#         pyprintf("Measured Time elapsed : %d\n", (int)elapsed_ms);
#         pyprintf("======================\n");
#     }
#
#     return 0;
# }
#
# int test_timer_long_delay(){
#     timer_init_ms();
#     pyprintf("Starting 50-second delay...\n");
#
#     uint32_t start_ms = get_timer_ms();
#     // Delay for 50,000 ms (50 seconds)
#     mb_delay_ms(50000);
#     uint32_t end_ms = get_timer_ms();
#
#     pyprintf("Start : %d\n", (int)start_ms);
#     pyprintf("End : %d\n", (int)end_ms);
#     pyprintf("Measured Time elapsed : %d\n", (int)(end_ms - start_ms));
#     // The code should hang inside mb_delay_ms, and this line may never execute.
#     // If it *does* execute, the Measured Time elapsed will be incorrect, likely showing ~42949ms or similar.
#     return 0;
# }

# %%
a = test_gyro()
# Out:
# Start
# I2C Open...
# FINISHED SETUP, READING GYRO...
# ...
# fx=0.000000, fy=0.000000, fz=0.000000
# ...
# fx=0.000000, fy=0.000000, fz=0.000000
# ...
# fx=0.000000, fy=0.000000, fz=0.000000
# ...
# fx=0.000000, fy=0.000000, fz=0.000000
# ...
# fx=0.000000, fy=0.000000, fz=0.000000
# ...
# fx=0.000000, fy=0.000000, fz=0.000000
# ...
# fx=0.000000, fy=0.000000, fz=0.000000
# ...
# fx=0.000000, fy=0.000000, fz=0.000000
# ...
# fx=0.000000, fy=0.000000, fz=0.000000
# ...
# fx=0.000000, fy=0.000000, fz=0.000000
# ...
# fx=0.000000, fy=0.000000, fz=0.000000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 a = test_gyro()
#
# File /usr/local/share/pynq-venv/lib/python3.10/site-packages/pynq/lib/pynqmicroblaze/magic.py:25, in _FunctionWrapper.__call__(self, *args)
#      24 def __call__(self, *args):
# ---> 25     return self._function(*args)
#
# File <string>:3, in call(self)
#
# ...

# %%
a = test_motor_init()
# Out:
# Starting Motors init...
# 1
# 2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [33], in <cell line: 1>()
# ----> 1 a = test_motor_init()
#
# File /usr/local/share/pynq-venv/lib/python3.10/site-packages/pynq/lib/pynqmicroblaze/magic.py:25, in _FunctionWrapper.__call__(self, *args)
#      24 def __call__(self, *args):
# ---> 25     return self._function(*args)
#
# File <string>:3, in call(self)
#
# File /usr/local/share/pynq-venv/lib/python3.10/site-packages/pynq/lib/pynqmicroblaze/rpc.py:883, in MicroblazeFunction.call(self, *args)
#     881 done = False
#     882 while not done:
# --> 883     return_value, done = self._handle_stream(*args)
#     885 if self.return_type:
#     886     return self.return_type(return_value)
#
# ...

# %%
c = test_motor_stop()

# %%
d = test_timer()
# Out:
# ======================LOOP: 0
# Start : 0
# End : 100
# Measured Time elapsed : 100
# ...
# ======================LOOP: 1
# Start : 100
# End : 200
# Measured Time elapsed : 100
# ...
# ======================LOOP: 2
# Start : 200
# End : 300
# Measured Time elapsed : 100
# ...
# ======================LOOP: 3
# Start : 300
# End : 400
# Measured Time elapsed : 100
# ...
# ======================LOOP: 4
# Start : 400
# End : 500
# Measured Time elapsed : 100
# ...
# ======================LOOP: 5
# Start : 500
# End : 600
# Measured Time elapsed : 100
# ...
# ======================LOOP: 6
# Start : 600
# End : 700
# Measured Time elapsed : 100
# ...
# ======================LOOP: 7
# Start : 700
# End : 800
# Measured Time elapsed : 100
# ...
# ======================LOOP: 8
# Start : 800
# End : 900
# Measured Time elapsed : 100
# ...
# ======================LOOP: 9
# Start : 900
# End : 1000
# Measured Time elapsed : 100
# ...
# ======================LOOP: 10
# Start : 1000
# End : 1100
# Measured Time elapsed : 100
# ...

# %%
e = test_timer_long_delay()

# %%
f = test_timer()
# Out:
# ======================LOOP: 0
# Start : 0
# End : 100
# Measured Time elapsed : 100
# ...
# ======================LOOP: 1
# Start : 100
# End : 200
# Measured Time elapsed : 100
# ...
# ======================LOOP: 2
# Start : 200
# End : 300
# Measured Time elapsed : 100
# ...
# ======================LOOP: 3
# Start : 300
# End : 400
# Measured Time elapsed : 100
# ...
# ======================LOOP: 4
# Start : 400
# End : 500
# Measured Time elapsed : 100
# ...
# ======================LOOP: 5
# Start : 500
# End : 600
# Measured Time elapsed : 100
# ...
# ======================LOOP: 6
# Start : 600
# End : 700
# Measured Time elapsed : 100
# ...
# ======================LOOP: 7
# Start : 700
# End : 800
# Measured Time elapsed : 100
# ...
# ======================LOOP: 8
# Start : 800
# End : 900
# Measured Time elapsed : 100
# ...
# ======================LOOP: 9
# Start : 900
# End : 1000
# Measured Time elapsed : 100
# ...
# ======================LOOP: 10
# Start : 1000
# End : 1100
# Measured Time elapsed : 100
# ...

# %% [markdown]
# # RPI

# %%
from pynq.overlays.base import BaseOverlay
from pynq.lib import MicroblazeLibrary

base = BaseOverlay("base.bit")
base.select_rpi()

# %%
# %%microblaze base.RPI
#
# # include <stdint.h>
# # include <string.h>
# #include "xio_switch.h"
# #include "xparameters.h"
#
# /* PYNQ MicroBlaze headers  */
# #include <i2c.h>
# #include <pyprintf.h>
#
#
# #define MB_CLOCK_FREQ_HZ 100000000
#
# #define TMR_BASEADDR XPAR_TMRCTR_0_BASEADDR
# #define TMR_TCSR1 (*(volatile uint32_t *)(TMR_BASEADDR + 0x10))
# #define TMR_TLR1 (*(volatile uint32_t *)(TMR_BASEADDR + 0x14))
# #define TMR_TCR1 (*(volatile uint32_t *)(TMR_BASEADDR + 0x18))
# #define TMR_CSR_LOAD_MASK 0x00000020 // Load Timer (set bit 5)
# #define TMR_CSR_ARHT_MASK 0x00000010 // Auto-Reload (set bit 4)
# #define TMR_CSR_ENT_MASK 0x00000080  // Enable Timer (set bit 7)
# #define TMR_CSR_GENT_MASK 0x00000004 // Generate Event (set bit 2)
# #define TMR_CSR_UDT_MASK 0x00000002  // Up/Down Timer (set bit 1)
#
#
#
# /* Mailbox addresses  */
# #define MAILBOX_BASE        0xF000
# #define MAILBOX_CMD_ADDR    (*(volatile unsigned int *)(0xFFFC))
# #define MAILBOX_DATA(i)     (*(volatile unsigned int *)(MAILBOX_BASE + ((i)*4)))
#
# /* Commands */
# #define CMD_NOP             0x0
# #define CMD_START_PID       0x1
# #define CMD_STOP_PID        0x2
# #define CMD_SET_GAINS       0x3
# #define CMD_SET_SETPOINTS   0x4
# #define CMD_HEARTBEAT       0x5
# #define CMD_GET_LOG         0x6
#
# /* Logging */
# #define LOG_BASE_ADDRESS    (MAILBOX_BASE + 16)
# #define LOG_ITEM_SIZE       sizeof(uint32_t)
# #define LOG_CAPACITY        (4000 / LOG_ITEM_SIZE)
#
# /* Constants from constant.py */
# #define TCA_DEVICE_ADDRESS      0x70
# #define TCA_MPU_CHANNEL         0
#
# #define MPU_DEVICE_ADDRESS      0x68
# #define MPU_PWR_MGMT_1          0x6B
# #define MPU_SMPLRT_DIV          0x19
# #define MPU_CONFIG              0x1A
# #define MPU_GYRO_CONFIG         0x1B
# #define MPU_INT_ENABLE          0x38
# #define MPU_ACCEL_XOUT_H        0x3B
# #define MPU_ACCEL_YOUT_H        0x3D
# #define MPU_ACCEL_ZOUT_H        0x3F
# #define MPU_GYRO_XOUT_H         0x43
# #define MPU_GYRO_YOUT_H         0x45
# #define MPU_GYRO_ZOUT_H         0x47
#
# #define PCA9685_ADDRESS         0x40
# #define PCA9685_MODE1           0x00
# #define PCA9685_MODE2           0x01
# #define PCA9685_PRESCALE        0xFE
# #define LED0_ON_L               0x06
# #define LED0_ON_H               0x07
# #define LED0_OFF_L              0x08
# #define LED0_OFF_H              0x09
# #define PCA9685_SLEEP           0x10
# #define PCA9685_ALLCALL         0x01
# #define PCA9685_OUTDRV          0x04
# #define PCA9685_AI              0x20  // Auto-Increment Bit (Bit 5 of MODE1)
#
# #define PMOD_TCA_SDA_PIN 3
# #define PMOD_TCA_SCL_PIN 2
# #define PMOD_MOTOR_SDA_PIN 1
# #define PMOD_MOTOR_SCL_PIN 0
#
#
# /* Motor microsecond range */
# #define MIN_MOTOR_US 1000
# #define MAX_MOTOR_US 2000
#
# /* Q16.16 helpers */
# typedef int32_t q16;
# #define Q16_ONE (1<<16)
# static inline q16 float_to_q16(float f)  { return (q16)(f * (float)Q16_ONE); }
# static inline float q16_to_float(q16 q)  { return ((float)q) / (float)Q16_ONE; }
# static inline q16 q16_mul(q16 a, q16 b)  { return (q16)(((int64_t)a * (int64_t)b) >> 16); }
# static inline q16 q16_div(q16 a, q16 b)  { return (q16)((((int64_t)a << 16) / (int64_t)b)); }
#
#
# /* PID struct */
# typedef struct {
#     q16 kp, ki, kd;
#     q16 integ;
#     q16 last_err;
#     q16 out_min, out_max;
# } pid_type;
#
# /* Globals */
# volatile uint32_t *log_ptr = (volatile uint32_t*)LOG_BASE_ADDRESS;
# uint32_t log_index = 0;
#
# i2c i2c_tca;
# i2c i2c_motor;
#
# pid_type pid_roll, pid_pitch, pid_yaw;
#
# void mb_i2c_open(void);
# int i2c_write_reg(uint8_t dev_addr, uint8_t reg, const uint8_t *data, int len);
# int i2c_read_reg(uint8_t dev_addr, uint8_t reg, uint8_t *buf, int len);
#
# void tca_select_channel(uint8_t channel);
#
# void pca_write8(uint8_t reg, uint8_t value);
# uint8_t pca_read8(uint8_t reg);
# void pca9685_init(void);
# void pca9685_set_pwm(int motor, uint16_t on, uint16_t off);
# uint16_t us_to_pca_value(int us);
# void pca9685_set_pwm_us(int motor, int us);
#
# void mpu_init(void);
# int16_t mpu_read_raw16(uint8_t reg);
# void mpu_read_gyro(q16 *gx, q16 *gy, q16 *gz);
#
# void mb_write_motor_pwm_from_q16(int motor, q16 norm_q16, int min_us, int max_us);
# q16 pid_step(pid_type *p, q16 setpoint, q16 measurement, q16 dt_q16);
# void mb_delay_ms(uint32_t ms);
#
# void timer_init_ms()
# {
#     TMR_TLR1 = 0;
#     TMR_TCSR1 = TMR_CSR_LOAD_MASK;
#     TMR_TCSR1 = TMR_CSR_ENT_MASK | TMR_CSR_ARHT_MASK | TMR_CSR_GENT_MASK ;
# }
#
# uint32_t get_timer_ms(void)
# {
#     uint32_t current_count = TMR_TCR1;
#     uint32_t elapsed_ms = (uint32_t)((uint64_t)current_count * 1000 / MB_CLOCK_FREQ_HZ);
#     return elapsed_ms;
# }
#
#
# void mb_i2c_open(void)
# {
#     init_io_switch();
#
#     set_pin(PMOD_MOTOR_SCL_PIN, SCL0);
#     set_pin(PMOD_MOTOR_SDA_PIN, SDA0);
#
#     set_pin(PMOD_TCA_SCL_PIN, SCL1);
#     set_pin(PMOD_TCA_SDA_PIN, SDA1);
#     mb_delay_ms(100);
#
#     //i2c_motor = i2c_open(PMOD_MOTOR_SDA_PIN, PMOD_MOTOR_SCL_PIN);
#     //i2c_tca = i2c_open(PMOD_TCA_SDA_PIN, PMOD_TCA_SCL_PIN);
#
#     i2c_motor = i2c_open_device(0);
#     i2c_tca = i2c_open_device(1);
#
#     mb_delay_ms(100);
#     tca_select_channel(TCA_MPU_CHANNEL);
# }
#
#
# int i2c_tca_write_reg(uint8_t dev_addr, uint8_t reg, const uint8_t *data, int len) {
#     unsigned char buf[32];
#     if (len + 1 > (int)sizeof(buf)) return -1;
#     buf[0] = reg;
#     memcpy(&buf[1], data, len);
#     return i2c_write(i2c_tca, dev_addr, buf, len + 1);
# }
#
# int i2c_tca_read_reg(uint8_t dev_addr, uint8_t reg, uint8_t *buf, int len) {
#     uint8_t tx = reg;
#     i2c_write(i2c_tca, dev_addr, (unsigned char*)&tx, 1);
#     return i2c_read(i2c_tca, dev_addr, (unsigned char*)buf, len);
# }
#
# int i2c_motor_write_reg(uint8_t dev_addr, uint8_t reg, const uint8_t *data, int len)
# {
#     unsigned char buf[32];
#     if (len + 1 > (int)sizeof(buf)) return -1;
#     buf[0] = reg;
#     memcpy(&buf[1], data, len);
#     return i2c_write(i2c_motor, dev_addr, buf, len + 1);
# }
#
# int i2c_motor_read_reg(uint8_t dev_addr, uint8_t reg, uint8_t *buf, int len)
# {
#     uint8_t tx = reg;
#     i2c_write(i2c_motor, dev_addr, (unsigned char *)&tx, 1);
#     return i2c_read(i2c_motor, dev_addr, (unsigned char *)buf, len);
# }
#
# void tca_select_channel(uint8_t channel) {
#     if (channel > 7) return;
#     uint8_t mask = (uint8_t)(1 << channel);
#     // TCA9548A is NOT register-based. It expects a single byte (the mask) written
#     // to its address to select the channel. Use i2c_write directly.
#     i2c_write(i2c_tca, TCA_DEVICE_ADDRESS, &mask, 1);
# }
#
#
# void pca9685_set_pwm(int motor, uint16_t on, uint16_t off)
# {
#     int ch;
#     switch (motor)
#     {
#     case 1: ch = 3; break;
#     case 2: ch = 4; break;
#     case 3: ch = 7; break;
#     case 4: ch = 8; break;
#     default: return;
#     }
#
#     uint8_t ON_L = LED0_ON_L + 4 * ch;
#
#     // Create a buffer with all 4 bytes
#     uint8_t payload[4];
#     payload[0] = on & 0xFF;
#     payload[1] = (on >> 8) & 0x0F;
#     payload[2] = off & 0xFF;
#     payload[3] = (off >> 8) & 0x0F;
#
#     // Write all 4 bytes in ONE transaction
#     // i2c_write_reg automatically sends the Register address (ON_L)
#     // followed by the 4 bytes of data. The PCA9685 auto-increments the
#     // internal pointer to ON_H, OFF_L, OFF_H automatically.
#     i2c_motor_write_reg(PCA9685_ADDRESS, ON_L, payload, 4);
# }
#
#
#
# /* convert microseconds to 12-bit PCA value */
# uint16_t us_to_pca_value(int us) {
#     uint32_t v = ((uint32_t)us * 4096U) / 20000U; /* int math of us * 4096 / 20000 */
#     if (v > 4095U) v = 4095U;
#     return (uint16_t)v;
# }
# void pca9685_set_pwm_us(int motor, int us) {
#     uint16_t val = us_to_pca_value(us);
#     pca9685_set_pwm(motor, 0, val);
# }
#
#
# void pca_write8(uint8_t reg, uint8_t value) {
#     i2c_motor_write_reg(PCA9685_ADDRESS, reg, &value, 1);
# }
#
# uint8_t pca_read8(uint8_t reg) {
#     uint8_t v = 0;
#     i2c_motor_read_reg(PCA9685_ADDRESS, reg, &v, 1);
#     return v;
# }
# void pca9685_init(void)
# {
#     pca_write8(PCA9685_MODE1, PCA9685_OUTDRV);
#     pyprintf("1\n");
#     pca_write8(PCA9685_MODE1, PCA9685_ALLCALL);
#     pyprintf("2\n");
#     mb_delay_ms(5);
#     pyprintf("3\n");
#     uint8_t mode1 = pca_read8(PCA9685_MODE1);
#     mode1 &= ~PCA9685_SLEEP; // Wake up
#     pyprintf("4\n");
#     pca_write8(PCA9685_MODE1, mode1);
#     pyprintf("5\n");
#     mb_delay_ms(5);
#     pyprintf("6\n");
#
#     // Set Prescale
#     float freq = 1000.0f;
#     float prescaleval = 25000000.0f / (4096.0f * freq) - 1.0f;
#     int prescale = (int)(prescaleval + 0.5f);
#
#     uint8_t oldmode = pca_read8(PCA9685_MODE1);
#     uint8_t newmode = (oldmode & 0x7F) | 0x10; // Sleep to set prescale
#     pca_write8(PCA9685_MODE1, newmode);
#     pca_write8(PCA9685_PRESCALE, (uint8_t)prescale);
#
#     pca_write8(PCA9685_MODE1, oldmode);
#     mb_delay_ms(5);
#
#     // IMPORTANT: Enable Auto-Increment (PCA9685_AI) here
#     // This sets bit 5 HIGH, allowing us to write sequential registers in one go
#     pca_write8(PCA9685_MODE1, oldmode | 0x80 | PCA9685_AI);
# }
#
# /* MPU init and read */
# void mpu_init(void) {
#     tca_select_channel(TCA_MPU_CHANNEL);
#     uint8_t tmp;
#     tmp = 7; i2c_tca_write_reg(MPU_DEVICE_ADDRESS, MPU_SMPLRT_DIV, &tmp, 1); mb_delay_ms(100);
#     tmp = 1; i2c_tca_write_reg(MPU_DEVICE_ADDRESS, MPU_PWR_MGMT_1, &tmp, 1); mb_delay_ms(100);
#     tmp = 0; i2c_tca_write_reg(MPU_DEVICE_ADDRESS, MPU_CONFIG, &tmp, 1); mb_delay_ms(100);
#     tmp = 24; i2c_tca_write_reg(MPU_DEVICE_ADDRESS, MPU_GYRO_CONFIG, &tmp, 1); mb_delay_ms(100);
#     tmp = 1; i2c_tca_write_reg(MPU_DEVICE_ADDRESS, MPU_INT_ENABLE, &tmp, 1); mb_delay_ms(100);
# }
#
# /* read 16-bit signed big-endian from MPU */
# int16_t mpu_read_raw16(uint8_t reg) {
#     uint8_t buf[2];
#     i2c_tca_read_reg(MPU_DEVICE_ADDRESS, reg, buf, 2);
#     return (int16_t)((buf[0] << 8) | buf[1]);
# }
#
#
# /* read gyro scaled to deg/s and convert to Q16 */
# /*void mpu_read_gyro(q16 *gx, q16 *gy, q16 *gz) {
#     tca_select_channel(TCA_MPU_CHANNEL);
#     int16_t rx = mpu_read_raw16(MPU_GYRO_XOUT_H);
#     int16_t ry = mpu_read_raw16(MPU_GYRO_YOUT_H);
#     int16_t rz = mpu_read_raw16(MPU_GYRO_ZOUT_H);
#     float fx = ((float)rx) / 131.0f;
#     float fy = ((float)ry) / 131.0f;
#     float fz = ((float)rz) / 131.0f;
#     *gx = float_to_q16(fx);
#     *gy = float_to_q16(fy);
#     *gz = float_to_q16(fz);
# }
# */
# void mpu_read_gyro(q16 *gx, q16 *gy, q16 *gz)
# {
#     uint8_t buf[6];
#
#     //tca_select_channel(TCA_MPU_CHANNEL);
#
#     int ret = i2c_tca_read_reg(MPU_DEVICE_ADDRESS, MPU_GYRO_XOUT_H, buf, 6);
#
#     int16_t rx = (int16_t)((buf[0] << 8) | buf[1]);
#     int16_t ry = (int16_t)((buf[2] << 8) | buf[3]);
#     int16_t rz = (int16_t)((buf[4] << 8) | buf[5]);
#
#     const int32_t GYRO_SCALE_DIV = 131;
#
#     *gx = float_to_q16((float)rx / GYRO_SCALE_DIV);
#     *gy = float_to_q16(-(float)ry / GYRO_SCALE_DIV);
#     *gz = float_to_q16(-(float)rz / GYRO_SCALE_DIV);
# }
#
#
# /* convert Q16 normalized throttle [0..1] to PCA microseconds and set pwm */
# void mb_write_motor_pwm_from_q16(int motor, q16 norm_q16, int min_us, int max_us) {
#     float f = q16_to_float(norm_q16);
#     if (f < 0.0f) f = 0.0f;
#     if (f > 1.0f) f = 1.0f;
#     int us = (int)(min_us + f * (max_us - min_us));
#     pca9685_set_pwm_us(motor, us);
# }
#
# void arm_motor(int ch){
#     pca9685_set_pwm_us(ch, MIN_MOTOR_US);
#     mb_delay_ms(1000);
#     pca9685_set_pwm_us(ch, MAX_MOTOR_US);
#     mb_delay_ms(1000);
#     pca9685_set_pwm_us(ch, MIN_MOTOR_US);
#     mb_delay_ms(1000);
# }
#
# /*
# void arm_motors(){
#     for(int i = 1; i <= 4; i++){
#         pca9685_set_pwm_us(i, MIN_MOTOR_US);
#         mb_delay_ms(1000);
#         pca9685_set_pwm_us(i, MAX_MOTOR_US);
#         mb_delay_ms(1000);
#         pca9685_set_pwm_us(i, MIN_MOTOR_US);
#         mb_delay_ms(1000);
#     }
#     mb_delay_ms(1000);
#     pyprintf("ARMING SEQUENCE DONE\n");
# }
# */
#
# void arm_all(){
#     for(int i = 1; i <= 4; i++){
#         arm_motor(i);
#     }
#     mb_delay_ms(1000);
#     pyprintf("ARMING SEQUENCE DONE\n");
# }
#
# void motors_init(){
#     pyprintf("Starting Motors init...\n");
#     pca9685_init();
#     pyprintf("PCA init done...\n");
#     arm_all();
# }
#
#
# /* ========================================TEST================================== */
# int test_gyro() {
#     pyprintf("Start\n");
#     timer_init_ms();
#     mb_i2c_open();
#     pyprintf("I2C Open...\n");
#     mpu_init();
#     pyprintf("FINISHED SETUP, READING GYRO...\n");
#
#
#     while (1) {
#         pyprintf("=============================\n");
#
#
#         /*int16_t rx = mpu_read_raw16(MPU_GYRO_XOUT_H);
#         int16_t ry = mpu_read_raw16(MPU_GYRO_YOUT_H);
#         int16_t rz = mpu_read_raw16(MPU_GYRO_ZOUT_H);
#
#         float fx = ((float)rx) / 131.0f;
#         float fy = ((float)ry) / 131.0f;
#         float fz = ((float)rz) / 131.0f;*/
#
#
#         q16 gx, gy, gz;
#         mpu_read_gyro(&gx, &gy, &gz);
#         float fx = q16_to_float(gx);
#         float fy = q16_to_float(gy);
#         float fz = q16_to_float(gz);
#
#         pyprintf("fx=%f, fy=%f, fz=%f\n", fx, fy, fz);
#
#         mb_delay_ms(500);
#     }
#
#     return 0;
# }
#
#
# int test_motor_init(){
#     timer_init_ms();
#     mb_i2c_open();
#     motors_init();
#      //mpu_init();
#     return 0;
# }
#
#
# int test_motor_start(){
#     int speed_us = 1050;
#     for(int i = 1; i <= 4; i++){
#         pca9685_set_pwm_us(i, speed_us);
#     }
#     pyprintf("motor started with speed : %d", speed_us);
#     return 0;
# }
#
# int test_motor_stop(){
#     int speed_us = 0;
#     for(int i = 1; i <= 4; i++){
#         pca9685_set_pwm_us(i, speed_us);
#     }
#     pyprintf("motor stopped with speed : %d", speed_us);
#     return 0;
# }
#
# void mb_delay_ms(uint32_t ms)
# {
#     uint32_t start = get_timer_ms();
#     // Use unsigned 32-bit subtraction, which handles timer rollover correctly
#     while ((get_timer_ms() - start) < ms);
# }
#
#
# int test_timer(){
#     timer_init_ms();
#     for(int i = 0; i<1000; i++){
#         pyprintf("======================LOOP: %d\n", i);
#         uint32_t start_ms = get_timer_ms();
#         mb_delay_ms(100);
#         uint32_t end_ms = get_timer_ms();
#         uint32_t elapsed_ms = end_ms - start_ms;
#         pyprintf("Start : %d\n", (int)start_ms);
#         pyprintf("End : %d\n", (int)end_ms);
#         pyprintf("Measured Time elapsed : %d\n", (int)elapsed_ms);
#         pyprintf("======================\n");
#     }
#
#     return 0;
# }
#
# int test_timer_long_delay(){
#     timer_init_ms();
#     pyprintf("Starting 50-second delay...\n");
#
#     uint32_t start_ms = get_timer_ms();
#     // Delay for 50,000 ms (50 seconds)
#     mb_delay_ms(50000);
#     uint32_t end_ms = get_timer_ms();
#
#     pyprintf("Start : %d\n", (int)start_ms);
#     pyprintf("End : %d\n", (int)end_ms);
#     pyprintf("Measured Time elapsed : %d\n", (int)(end_ms - start_ms));
#     // The code should hang inside mb_delay_ms, and this line may never execute.
#     // If it *does* execute, the Measured Time elapsed will be incorrect, likely showing ~42949ms or similar.
#     return 0;
# }

# %%
a = test_gyro()
# Out:
# Start
# I2C Open...
# FINISHED SETUP, READING GYRO...
# ...
# fx=-0.343506, fy=0.282440, fz=-0.259537
# ...
# fx=-0.335876, fy=0.290070, fz=-0.274796
# ...
# fx=-0.343506, fy=0.282440, fz=-0.229004
# ...
# fx=-0.358765, fy=0.290070, fz=-0.236633
# ...
# fx=-0.335876, fy=0.267166, fz=-0.267166
# ...
# fx=-0.351135, fy=0.259537, fz=-0.259537
# ...
# fx=-0.328232, fy=0.274796, fz=-0.259537
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [22], in <cell line: 1>()
# ----> 1 a = test_gyro()
#
# File /usr/local/share/pynq-venv/lib/python3.10/site-packages/pynq/lib/pynqmicroblaze/magic.py:25, in _FunctionWrapper.__call__(self, *args)
#      24 def __call__(self, *args):
# ---> 25     return self._function(*args)
#
# File <string>:3, in call(self)
#
# File /usr/local/share/pynq-venv/lib/python3.10/site-packages/pynq/lib/pynqmicroblaze/rpc.py:883, in MicroblazeFunction.call(self, *args)
#     881 done = False
# ...

# %%
a = test_motor_init()
# Out:
# Starting Motors init...
# 1
# 2
# 3
# 4
# 5
# 6
# PCA init done...
# ARMING SEQUENCE DONE

# %%
b = test_motor_start()
# Out:
# motor started with speed : 1050

# %%
c = test_motor_stop()
# Out:
# motor stopped with speed : 0

# %% [markdown]
# # CUSTOM NON BLOCKING IIC

# %%
from pynq.overlays.base import BaseOverlay
from pynq.lib import MicroblazeLibrary

base = BaseOverlay("base.bit")
base.select_rpi()

# %%
# %%microblaze base.RPI
#
# # include <stdint.h>
# # include <string.h>
# #include "xio_switch.h"
# #include "xparameters.h"
# #include "xiic_l.h"
# #include "xiic.h"
# /* PYNQ MicroBlaze headers  */
# #include <pyprintf.h>
#
#
# #define MB_CLOCK_FREQ_HZ 100000000
#
# #define TMR_BASEADDR XPAR_TMRCTR_0_BASEADDR
# #define TMR_TCSR1 (*(volatile uint32_t *)(TMR_BASEADDR + 0x10))
# #define TMR_TLR1 (*(volatile uint32_t *)(TMR_BASEADDR + 0x14))
# #define TMR_TCR1 (*(volatile uint32_t *)(TMR_BASEADDR + 0x18))
# #define TMR_CSR_LOAD_MASK 0x00000020 // Load Timer (set bit 5)
# #define TMR_CSR_ARHT_MASK 0x00000010 // Auto-Reload (set bit 4)
# #define TMR_CSR_ENT_MASK 0x00000080  // Enable Timer (set bit 7)
# #define TMR_CSR_GENT_MASK 0x00000004 // Generate Event (set bit 2)
# #define TMR_CSR_UDT_MASK 0x00000002  // Up/Down Timer (set bit 1)
#
#
#
# /* Mailbox addresses  */
# #define MAILBOX_BASE        0xF000
# #define MAILBOX_CMD_ADDR    (*(volatile unsigned int *)(0xFFFC))
# #define MAILBOX_DATA(i)     (*(volatile unsigned int *)(MAILBOX_BASE + ((i)*4)))
#
# /* Commands */
# #define CMD_NOP             0x0
# #define CMD_START_PID       0x1
# #define CMD_STOP_PID        0x2
# #define CMD_SET_GAINS       0x3
# #define CMD_SET_SETPOINTS   0x4
# #define CMD_HEARTBEAT       0x5
# #define CMD_GET_LOG         0x6
#
# /* Logging */
# #define LOG_BASE_ADDRESS    (MAILBOX_BASE + 16)
# #define LOG_ITEM_SIZE       sizeof(uint32_t)
# #define LOG_CAPACITY        (4000 / LOG_ITEM_SIZE)
#
# /* Constants from constant.py */
# #define TCA_DEVICE_ADDRESS      0x70
# #define TCA_MPU_CHANNEL         0
#
# #define MPU_DEVICE_ADDRESS      0x68
# #define MPU_PWR_MGMT_1          0x6B
# #define MPU_SMPLRT_DIV          0x19
# #define MPU_CONFIG              0x1A
# #define MPU_GYRO_CONFIG         0x1B
# #define MPU_INT_ENABLE          0x38
# #define MPU_ACCEL_XOUT_H        0x3B
# #define MPU_ACCEL_YOUT_H        0x3D
# #define MPU_ACCEL_ZOUT_H        0x3F
# #define MPU_GYRO_XOUT_H         0x43
# #define MPU_GYRO_YOUT_H         0x45
# #define MPU_GYRO_ZOUT_H         0x47
#
# #define PCA9685_ADDRESS         0x40
# #define PCA9685_MODE1           0x00
# #define PCA9685_MODE2           0x01
# #define PCA9685_PRESCALE        0xFE
# #define LED0_ON_L               0x06
# #define LED0_ON_H               0x07
# #define LED0_OFF_L              0x08
# #define LED0_OFF_H              0x09
# #define PCA9685_SLEEP           0x10
# #define PCA9685_ALLCALL         0x01
# #define PCA9685_OUTDRV          0x04
# #define PCA9685_AI              0x20  // Auto-Increment Bit (Bit 5 of MODE1)
#
# #define PMOD_TCA_SDA_PIN 3
# #define PMOD_TCA_SCL_PIN 2
# #define PMOD_MOTOR_SDA_PIN 1
# #define PMOD_MOTOR_SCL_PIN 0
#
# #define IIC_TIMEOUT_MAX  100000
# #define MOTOR_IIC_BASE   XPAR_IO_SWITCH_0_I2C0_BASEADDR
# #define TCA_IIC_BASE     XPAR_IO_SWITCH_0_I2C1_BASEADDR
#
#
# /* Motor microsecond range */
# #define MIN_MOTOR_US 1000
# #define MAX_MOTOR_US 2000
#
#
#
#
# /* =========================================================================
#    2. NON-BLOCKING LOW-LEVEL DRIVERS (Integrated directly)
#    ========================================================================= */
#
# /* Helper: RecvData (Internal) */
# static unsigned MyRecvData(UINTPTR BaseAddress, u8 *BufferPtr, unsigned ByteCount, u8 Option) {
#     u32 CntlReg;
#     u32 IntrStatusMask;
#     volatile u32 IntrStatus;
#     volatile int Timeout;
#
#     while (ByteCount > 0) {
#         if (ByteCount == 1) IntrStatusMask = XIIC_INTR_ARB_LOST_MASK | XIIC_INTR_BNB_MASK;
#         else IntrStatusMask = XIIC_INTR_ARB_LOST_MASK | XIIC_INTR_TX_ERROR_MASK | XIIC_INTR_BNB_MASK;
#
#         /* Wait for FIFO with Timeout */
#         Timeout = IIC_TIMEOUT_MAX;
#         while (1) {
#             IntrStatus = XIic_ReadIisr(BaseAddress);
#             if (IntrStatus & XIIC_INTR_RX_FULL_MASK) break;
#             if (IntrStatus & IntrStatusMask) return ByteCount;
#             if (Timeout-- == 0) return ByteCount; // TIMEOUT
#         }
#
#         CntlReg = XIic_ReadReg(BaseAddress, XIIC_CR_REG_OFFSET);
#         if (ByteCount == 1 && Option == XIIC_STOP) {
#             XIic_WriteReg(BaseAddress, XIIC_CR_REG_OFFSET, XIIC_CR_ENABLE_DEVICE_MASK);
#         }
#         if (ByteCount == 2) {
#             XIic_WriteReg(BaseAddress, XIIC_CR_REG_OFFSET, CntlReg | XIIC_CR_NO_ACK_MASK);
#         }
#
#         *BufferPtr++ = (u8) XIic_ReadReg(BaseAddress, XIIC_DRR_REG_OFFSET);
#
#         if ((ByteCount == 1) && (Option == XIIC_REPEATED_START)) {
#             XIic_WriteReg(BaseAddress, XIIC_CR_REG_OFFSET,
#                  XIIC_CR_ENABLE_DEVICE_MASK | XIIC_CR_MSMS_MASK | XIIC_CR_REPEATED_START_MASK);
#         }
#
#         XIic_ClearIisr(BaseAddress, XIIC_INTR_RX_FULL_MASK | XIIC_INTR_TX_ERROR_MASK | XIIC_INTR_ARB_LOST_MASK);
#         ByteCount--;
#     }
#
#     if (Option == XIIC_STOP) {
#         Timeout = IIC_TIMEOUT_MAX;
#         while (1) {
#             if (XIic_ReadIisr(BaseAddress) & XIIC_INTR_BNB_MASK) break;
#             if (Timeout-- == 0) break;
#         }
#     }
#     return ByteCount;
# }
#
# /* Helper: SendData (Internal) */
# static unsigned MySendData(UINTPTR BaseAddress, u8 *BufferPtr, unsigned ByteCount, u8 Option) {
#     volatile u32 IntrStatus;
#     volatile int Timeout;
#
#     while (ByteCount > 0) {
#         Timeout = IIC_TIMEOUT_MAX;
#         while (1) {
#             IntrStatus = XIic_ReadIisr(BaseAddress);
#             if (IntrStatus & (XIIC_INTR_TX_ERROR_MASK | XIIC_INTR_ARB_LOST_MASK | XIIC_INTR_BNB_MASK)) return ByteCount;
#             if (IntrStatus & XIIC_INTR_TX_EMPTY_MASK) break;
#             if (Timeout-- == 0) return ByteCount; // TIMEOUT
#         }
#
#         if (ByteCount > 1) {
#             XIic_WriteReg(BaseAddress, XIIC_DTR_REG_OFFSET, *BufferPtr++);
#         } else {
#             if (Option == XIIC_STOP) {
#                 XIic_WriteReg(BaseAddress, XIIC_CR_REG_OFFSET, XIIC_CR_ENABLE_DEVICE_MASK | XIIC_CR_DIR_IS_TX_MASK);
#             }
#             XIic_WriteReg(BaseAddress, XIIC_DTR_REG_OFFSET, *BufferPtr++);
#         }
#         XIic_ClearIisr(BaseAddress, XIIC_INTR_TX_EMPTY_MASK);
#         ByteCount--;
#     }
#
#     if (Option == XIIC_STOP) {
#         Timeout = IIC_TIMEOUT_MAX;
#         while (1) {
#             if (XIic_ReadIisr(BaseAddress) & XIIC_INTR_BNB_MASK) break;
#             if (Timeout-- == 0) break;
#         }
#     }
#     return ByteCount;
# }
#
# /* Main Receive Function (Non-Blocking) */
# int MyXIic_Recv(UINTPTR BaseAddress, u8 Address, u8 *BufferPtr, unsigned ByteCount) {
#     u32 CntlReg;
#     volatile u32 StatusReg;
#     volatile int Timeout = IIC_TIMEOUT_MAX;
#
#     // Reset FIFO
#     XIic_WriteReg(BaseAddress, XIIC_RFD_REG_OFFSET, 0);
#
#     // Clear Interrupts
#     XIic_ClearIisr(BaseAddress, XIIC_INTR_RX_FULL_MASK | XIIC_INTR_TX_ERROR_MASK | XIIC_INTR_ARB_LOST_MASK);
#
#     // Send Address
#     XIic_Send7BitAddress(BaseAddress, Address, XIIC_READ_OPERATION);
#
#     // Start
#     CntlReg = XIIC_CR_MSMS_MASK | XIIC_CR_ENABLE_DEVICE_MASK;
#     if (ByteCount == 1) CntlReg |= XIIC_CR_NO_ACK_MASK;
#     XIic_WriteReg(BaseAddress, XIIC_CR_REG_OFFSET, CntlReg);
#
#     // Wait for Bus Busy
#     while ((XIic_ReadReg(BaseAddress, XIIC_SR_REG_OFFSET) & XIIC_SR_BUS_BUSY_MASK) == 0) {
#         if (Timeout-- == 0) return 0;
#     }
#     XIic_ClearIisr(BaseAddress, XIIC_INTR_BNB_MASK);
#
#     // Read Data
#     if (MyRecvData(BaseAddress, BufferPtr, ByteCount, XIIC_STOP) != 0) return 0; // Error if remaining != 0
#
#     // Cleanup
#     XIic_WriteReg(BaseAddress, XIIC_CR_REG_OFFSET, 0);
#     return ByteCount;
# }
#
# /* Main Send Function (Non-Blocking) */
# int MyXIic_Send(UINTPTR BaseAddress, u8 Address, u8 *BufferPtr, unsigned ByteCount) {
#     volatile u32 StatusReg;
#     volatile int Timeout = IIC_TIMEOUT_MAX;
#
#     // Wait Bus Free
#     while (XIic_ReadReg(BaseAddress, XIIC_SR_REG_OFFSET) & XIIC_SR_BUS_BUSY_MASK) {
#         if (Timeout-- == 0) return 0;
#     }
#
#     // Send Address
#     XIic_Send7BitAddress(BaseAddress, Address, XIIC_WRITE_OPERATION);
#     XIic_ClearIisr(BaseAddress, XIIC_INTR_TX_EMPTY_MASK | XIIC_INTR_TX_ERROR_MASK | XIIC_INTR_ARB_LOST_MASK);
#
#     // Start
#     XIic_WriteReg(BaseAddress, XIIC_CR_REG_OFFSET, XIIC_CR_MSMS_MASK | XIIC_CR_DIR_IS_TX_MASK | XIIC_CR_ENABLE_DEVICE_MASK);
#
#     // Wait Bus Busy
#     Timeout = IIC_TIMEOUT_MAX;
#     while ((XIic_ReadReg(BaseAddress, XIIC_SR_REG_OFFSET) & XIIC_SR_BUS_BUSY_MASK) == 0) {
#         if (Timeout-- == 0) return 0;
#     }
#     XIic_ClearIisr(BaseAddress, XIIC_INTR_BNB_MASK);
#
#     // Send Data
#     if (MySendData(BaseAddress, BufferPtr, ByteCount, XIIC_STOP) != 0) return 0; // Error if remaining != 0
#
#     // Cleanup
#     StatusReg = XIic_ReadReg(BaseAddress, XIIC_SR_REG_OFFSET);
#     while ((StatusReg & XIIC_SR_BUS_BUSY_MASK) != 0) {
#         StatusReg = XIic_ReadReg(BaseAddress, XIIC_SR_REG_OFFSET);
#         // No timeout here usually needed, but good practice to allow system to proceed
#     }
#     return ByteCount;
# }
#
# /* ========================================================================= */
#
#
# /* Q16.16 helpers */
# typedef int32_t q16;
# #define Q16_ONE (1<<16)
# static inline q16 float_to_q16(float f)  { return (q16)(f * (float)Q16_ONE); }
# static inline float q16_to_float(q16 q)  { return ((float)q) / (float)Q16_ONE; }
# static inline q16 q16_mul(q16 a, q16 b)  { return (q16)(((int64_t)a * (int64_t)b) >> 16); }
# static inline q16 q16_div(q16 a, q16 b)  { return (q16)((((int64_t)a << 16) / (int64_t)b)); }
#
#
# /* PID struct */
# typedef struct {
#     q16 kp, ki, kd;
#     q16 integ;
#     q16 last_err;
#     q16 out_min, out_max;
# } pid_type;
#
# /* Globals */
# volatile uint32_t *log_ptr = (volatile uint32_t*)LOG_BASE_ADDRESS;
# uint32_t log_index = 0;
#
# pid_type pid_roll, pid_pitch, pid_yaw;
#
# void tca_select_channel(uint8_t channel);
#
# void pca_write8(uint8_t reg, uint8_t value);
# uint8_t pca_read8(uint8_t reg);
# void pca9685_init(void);
# void pca9685_set_pwm(int motor, uint16_t on, uint16_t off);
# uint16_t us_to_pca_value(int us);
# void pca9685_set_pwm_us(int motor, int us);
#
# void mpu_init(void);
# int16_t mpu_read_raw16(uint8_t reg);
# void mpu_read_gyro(q16 *gx, q16 *gy, q16 *gz);
#
# void mb_write_motor_pwm_from_q16(int motor, q16 norm_q16, int min_us, int max_us);
# q16 pid_step(pid_type *p, q16 setpoint, q16 measurement, q16 dt_q16);
# void mb_delay_ms(uint32_t ms);
#
# void timer_init_ms()
# {
#     TMR_TLR1 = 0;
#     TMR_TCSR1 = TMR_CSR_LOAD_MASK;
#     TMR_TCSR1 = TMR_CSR_ENT_MASK | TMR_CSR_ARHT_MASK | TMR_CSR_GENT_MASK ;
# }
#
# uint32_t get_timer_ms(void)
# {
#     uint32_t current_count = TMR_TCR1;
#     uint32_t elapsed_ms = (uint32_t)((uint64_t)current_count * 1000 / MB_CLOCK_FREQ_HZ);
#     return elapsed_ms;
# }
#
#
# void setup_hardware() {
#     init_io_switch();
#
#     set_pin(PMOD_MOTOR_SCL_PIN, SCL0);
#     set_pin(PMOD_MOTOR_SDA_PIN, SDA0);
#
#     set_pin(PMOD_TCA_SCL_PIN, SCL1);
#     set_pin(PMOD_TCA_SDA_PIN, SDA1);
#
#     //XIic_Initialize((XIic*)NULL, 0);
#     //XIic_Initialize((XIic*)NULL, 1);
# }
#
# int i2c_tca_write_reg(uint8_t dev, uint8_t reg, uint8_t val) {
#     uint8_t buf[2];
#     buf[0] = reg;
#     buf[1] = val;
#     return MyXIic_Send(TCA_IIC_BASE, dev, buf, 2);
# }
#
# int i2c_tca_read_reg(uint8_t dev, uint8_t reg, uint8_t* val, int len) {
#     // MPU is on I2C 1
#     // Write Reg Address
#     if(MyXIic_Send(TCA_IIC_BASE, dev, &reg, 1) == 0) return 0;
#     // Read Data
#     return MyXIic_Recv(TCA_IIC_BASE, dev, val, len);
# }
#
# int i2c_motor_write_reg(uint8_t reg, uint8_t* data, int len) {
#     uint8_t buf[32];
#     buf[0] = reg;
#     memcpy(&buf[1], data, len);
#     // Motors are on I2C 0
#     return MyXIic_Send(MOTOR_IIC_BASE, PCA9685_ADDRESS, buf, len+1);
# }
#
# int i2c_motor_read_reg(uint8_t reg, uint8_t* buffer, int length) {
#     // 1. Send the register address we want to read (Write operation)
#     // Motors are on MOTOR_IIC_BASE (I2C 0)
#     if (MyXIic_Send(MOTOR_IIC_BASE, PCA9685_ADDRESS, &reg, 1) == 0) {
#         return 0; // Timeout or NACK
#     }
#
#     // 2. Read the data from the device (Read operation)
#     return MyXIic_Recv(MOTOR_IIC_BASE, PCA9685_ADDRESS, buffer, length);
# }
#
# void tca_select_channel(uint8_t channel) {
#     if (channel > 7) return;
#     uint8_t mask = (1 << channel);
#     MyXIic_Send(TCA_IIC_BASE, TCA_DEVICE_ADDRESS, &mask, 1);
# }
#
#
# void pca9685_set_pwm(int motor, uint16_t on, uint16_t off)
# {
#     int ch;
#     switch (motor)
#     {
#     case 1: ch = 3; break;
#     case 2: ch = 4; break;
#     case 3: ch = 7; break;
#     case 4: ch = 8; break;
#     default: return;
#     }
#
#     uint8_t ON_L = LED0_ON_L + 4 * ch;
#
#     // Create a buffer with all 4 bytes
#     uint8_t payload[4];
#     payload[0] = on & 0xFF;
#     payload[1] = (on >> 8) & 0x0F;
#     payload[2] = off & 0xFF;
#     payload[3] = (off >> 8) & 0x0F;
#
#     // Write all 4 bytes in ONE transaction
#     // i2c_write_reg automatically sends the Register address (ON_L)
#     // followed by the 4 bytes of data. The PCA9685 auto-increments the
#     // internal pointer to ON_H, OFF_L, OFF_H automatically.
#     i2c_motor_write_reg(ON_L, payload, 4);
# }
#
#
#
# /* convert microseconds to 12-bit PCA value */
# uint16_t us_to_pca_value(int us) {
#     uint32_t v = ((uint32_t)us * 4096U) / 20000U; /* int math of us * 4096 / 20000 */
#     if (v > 4095U) v = 4095U;
#     return (uint16_t)v;
# }
# void pca9685_set_pwm_us(int motor, int us) {
#     uint16_t val = us_to_pca_value(us);
#     pca9685_set_pwm(motor, 0, val);
# }
#
#
# void pca_write8(uint8_t reg, uint8_t value) {
#     i2c_motor_write_reg(reg, &value, 1);
# }
#
# uint8_t pca_read8(uint8_t reg) {
#     uint8_t v = 0;
#     i2c_motor_read_reg(reg, &v, 1);
#     return v;
# }
# void pca9685_init(void)
# {
#     pca_write8(PCA9685_MODE1, PCA9685_OUTDRV);
#     pyprintf("1\n");
#     pca_write8(PCA9685_MODE1, PCA9685_ALLCALL);
#     pyprintf("2\n");
#     mb_delay_ms(5);
#     pyprintf("3\n");
#     uint8_t mode1 = pca_read8(PCA9685_MODE1);
#     mode1 &= ~PCA9685_SLEEP; // Wake up
#     pyprintf("4\n");
#     pca_write8(PCA9685_MODE1, mode1);
#     pyprintf("5\n");
#     mb_delay_ms(5);
#     pyprintf("6\n");
#
#     // Set Prescale
#     float freq = 1000.0f;
#     float prescaleval = 25000000.0f / (4096.0f * freq) - 1.0f;
#     int prescale = (int)(prescaleval + 0.5f);
#
#     uint8_t oldmode = pca_read8(PCA9685_MODE1);
#     uint8_t newmode = (oldmode & 0x7F) | 0x10; // Sleep to set prescale
#     pca_write8(PCA9685_MODE1, newmode);
#     pca_write8(PCA9685_PRESCALE, (uint8_t)prescale);
#
#     pca_write8(PCA9685_MODE1, oldmode);
#     mb_delay_ms(5);
#
#     // IMPORTANT: Enable Auto-Increment (PCA9685_AI) here
#     // This sets bit 5 HIGH, allowing us to write sequential registers in one go
#     pca_write8(PCA9685_MODE1, oldmode | 0x80 | PCA9685_AI);
# }
#
# /* MPU init and read */
# void mpu_init(void) {
#     tca_select_channel(TCA_MPU_CHANNEL);
#     uint8_t tmp;
#     tmp = 7; i2c_tca_write_reg(MPU_DEVICE_ADDRESS, MPU_SMPLRT_DIV, tmp); mb_delay_ms(100);
#     tmp = 1; i2c_tca_write_reg(MPU_DEVICE_ADDRESS, MPU_PWR_MGMT_1, tmp); mb_delay_ms(100);
#     tmp = 4; i2c_tca_write_reg(MPU_DEVICE_ADDRESS, MPU_CONFIG, tmp); mb_delay_ms(100);
#     tmp = 24; i2c_tca_write_reg(MPU_DEVICE_ADDRESS, MPU_GYRO_CONFIG, tmp); mb_delay_ms(100);
#     tmp = 1; i2c_tca_write_reg(MPU_DEVICE_ADDRESS, MPU_INT_ENABLE, tmp); mb_delay_ms(100);
# }
#
# /* read 16-bit signed big-endian from MPU */
# int16_t mpu_read_raw16(uint8_t reg) {
#     uint8_t buf[2];
#     i2c_tca_read_reg(MPU_DEVICE_ADDRESS, reg, buf, 2);
#     return (int16_t)((buf[0] << 8) | buf[1]);
# }
#
#
# /* read gyro scaled to deg/s and convert to Q16 */
# void mpu_read_gyro(q16 *gx, q16 *gy, q16 *gz)
# {
#     uint8_t buf[6];
#
#     //tca_select_channel(TCA_MPU_CHANNEL);
#
#     int ret = i2c_tca_read_reg(MPU_DEVICE_ADDRESS, MPU_GYRO_XOUT_H, buf, 6);
#
#     int16_t rx = (int16_t)((buf[0] << 8) | buf[1]);
#     int16_t ry = (int16_t)((buf[2] << 8) | buf[3]);
#     int16_t rz = (int16_t)((buf[4] << 8) | buf[5]);
#
#     const int32_t GYRO_SCALE_DIV = 131;
#
#     *gx = float_to_q16((float)rx / GYRO_SCALE_DIV);
#     *gy = float_to_q16(-(float)ry / GYRO_SCALE_DIV);
#     *gz = float_to_q16((float)rz / GYRO_SCALE_DIV);
# }
#
#
# /* convert Q16 normalized throttle [0..1] to PCA microseconds and set pwm */
# void mb_write_motor_pwm_from_q16(int motor, q16 norm_q16, int min_us, int max_us) {
#     float f = q16_to_float(norm_q16);
#     if (f < 0.0f) f = 0.0f;
#     if (f > 1.0f) f = 1.0f;
#     int us = (int)(min_us + f * (max_us - min_us));
#     pca9685_set_pwm_us(motor, us);
# }
#
# void arm_motor(int ch){
#     pca9685_set_pwm_us(ch, MIN_MOTOR_US);
#     mb_delay_ms(1000);
#     pca9685_set_pwm_us(ch, MAX_MOTOR_US);
#     mb_delay_ms(1000);
#     pca9685_set_pwm_us(ch, MIN_MOTOR_US);
#     mb_delay_ms(1000);
# }
#
# /*
# void arm_motors(){
#     for(int i = 1; i <= 4; i++){
#         pca9685_set_pwm_us(i, MIN_MOTOR_US);
#         mb_delay_ms(1000);
#         pca9685_set_pwm_us(i, MAX_MOTOR_US);
#         mb_delay_ms(1000);
#         pca9685_set_pwm_us(i, MIN_MOTOR_US);
#         mb_delay_ms(1000);
#     }
#     mb_delay_ms(1000);
#     pyprintf("ARMING SEQUENCE DONE\n");
# }
# */
#
# void arm_all(){
#     for(int i = 1; i <= 4; i++){
#         arm_motor(i);
#     }
#     mb_delay_ms(1000);
#     pyprintf("ARMING SEQUENCE DONE\n");
# }
#
# void motors_init(){
#     pyprintf("Starting Motors init...\n");
#     pca9685_init();
#     pyprintf("PCA init done...\n");
#     arm_all();
# }
#
# void mb_delay_ms(uint32_t ms)
# {
#     uint32_t start = get_timer_ms();
#     // Use unsigned 32-bit subtraction, which handles timer rollover correctly
#     while ((get_timer_ms() - start) < ms);
# }
#
#
# /* ========================================TEST================================== */
# int test_gyro() {
#     pyprintf("Start\n");
#     timer_init_ms();
#     setup_hardware();
#     pyprintf("I2C Open...\n");
#     mpu_init();
#     pyprintf("FINISHED SETUP, READING GYRO...\n");
#
#
#     while (1) {
#         pyprintf("=============================\n");
#
#
#         /*int16_t rx = mpu_read_raw16(MPU_GYRO_XOUT_H);
#         int16_t ry = mpu_read_raw16(MPU_GYRO_YOUT_H);
#         int16_t rz = mpu_read_raw16(MPU_GYRO_ZOUT_H);
#
#         float fx = ((float)rx) / 131.0f;
#         float fy = ((float)ry) / 131.0f;
#         float fz = ((float)rz) / 131.0f;*/
#
#
#         q16 gx, gy, gz;
#         mpu_read_gyro(&gx, &gy, &gz);
#         float fx = q16_to_float(gx);
#         float fy = q16_to_float(gy);
#         float fz = q16_to_float(gz);
#
#         pyprintf("fx=%f, fy=%f, fz=%f\n", fx, fy, fz);
#
#         mb_delay_ms(500);
#     }
#
#     return 0;
# }
#
#
# int test_motor_init(){
#     timer_init_ms();
#     setup_hardware();
#     motors_init();
#     return 0;
# }
#
#
# int test_motor_start(){
#     int speed_us = 1050;
#     for(int i = 1; i <= 4; i++){
#         pca9685_set_pwm_us(i, speed_us);
#     }
#     pyprintf("motor started with speed : %d", speed_us);
#     return 0;
# }
#
# int test_motor_stop(){
#     int speed_us = 0;
#     for(int i = 1; i <= 4; i++){
#         pca9685_set_pwm_us(i, speed_us);
#     }
#     pyprintf("motor stopped with speed : %d", speed_us);
#     return 0;
# }
#
#
#
#
# int test_timer(){
#     timer_init_ms();
#     for(int i = 0; i<1000; i++){
#         pyprintf("======================LOOP: %d\n", i);
#         uint32_t start_ms = get_timer_ms();
#         mb_delay_ms(100);
#         uint32_t end_ms = get_timer_ms();
#         uint32_t elapsed_ms = end_ms - start_ms;
#         pyprintf("Start : %d\n", (int)start_ms);
#         pyprintf("End : %d\n", (int)end_ms);
#         pyprintf("Measured Time elapsed : %d\n", (int)elapsed_ms);
#         pyprintf("======================\n");
#     }
#
#     return 0;
# }
#
# int test_timer_long_delay(){
#     timer_init_ms();
#     pyprintf("Starting 50-second delay...\n");
#
#     uint32_t start_ms = get_timer_ms();
#     // Delay for 50,000 ms (50 seconds)
#     mb_delay_ms(50000);
#     uint32_t end_ms = get_timer_ms();
#
#     pyprintf("Start : %d\n", (int)start_ms);
#     pyprintf("End : %d\n", (int)end_ms);
#     pyprintf("Measured Time elapsed : %d\n", (int)(end_ms - start_ms));
#     // The code should hang inside mb_delay_ms, and this line may never execute.
#     // If it *does* execute, the Measured Time elapsed will be incorrect, likely showing ~42949ms or similar.
#     return 0;
# }

# %%
a = test_gyro()
# Out:
# Start
# I2C Open...
# FINISHED SETUP, READING GYRO...
# ...
# fx=-0.343506, fy=0.267166, fz=0.259537
# ...
# fx=-0.343506, fy=0.259537, fz=0.251907
# ...
# fx=-0.358765, fy=0.267166, fz=0.259537
# ...
# fx=-0.343506, fy=0.267166, fz=0.259537
# ...
# fx=-0.343506, fy=0.267166, fz=0.259537
# ...
# fx=-0.351135, fy=0.267166, fz=0.251907
# ...
# fx=-0.335876, fy=0.244263, fz=0.259537
# ...
# fx=-0.335876, fy=0.236633, fz=0.259537
# ...
# fx=-0.297699, fy=0.198471, fz=0.015259
# ...
# fx=-0.473282, fy=0.061066, fz=-4.893127
# ...
# fx=-0.419846, fy=0.290070, fz=0.251907
# ...
# fx=-0.358765, fy=0.267166, fz=0.251907
# ...
# fx=-0.351135, fy=0.267166, fz=0.259537
# ...
# fx=-0.351135, fy=0.267166, fz=0.259537
# ...
# fx=-0.343506, fy=0.259537, fz=0.251907
# ...
# fx=-0.351135, fy=0.259537, fz=0.251907
# ...
# fx=-0.305328, fy=0.229004, fz=0.244263
# ...
# fx=-0.030533, fy=0.648849, fz=12.221375
# ...
# fx=-0.290070, fy=0.229004, fz=0.213730
# ...
# fx=-0.343506, fy=0.251907, fz=0.244263
# ...
# fx=-0.351135, fy=0.274796, fz=0.259537
# ...
# fx=-0.351135, fy=0.251907, fz=0.259537
# ...

# %%
=============================
fx=-0.335876, fy=0.259537, fz=-0.259537
=============================
fx=-0.335876, fy=0.274796, fz=-0.251907
=============================
fx=-0.351135, fy=0.267166, fz=-0.259537
=============================
fx=-0.343506, fy=0.267166, fz=-0.259537
=============================
fx=-0.343506, fy=0.267166, fz=-0.259537
=============================
fx=-0.343506, fy=0.267166, fz=-0.259537
=============================
fx=-0.343506, fy=0.267166, fz=-0.259537
=============================
fx=-0.343506, fy=0.259537, fz=-0.259537
=============================
fx=-0.343506, fy=0.267166, fz=-0.251907
=============================
fx=-0.335876, fy=0.259537, fz=-0.259537
=============================
fx=-0.343506, fy=0.274796, fz=-0.267166
=============================
fx=-0.343506, fy=0.267166, fz=-0.251907
=============================
fx=-0.343506, fy=0.259537, fz=-0.251907
=============================
fx=-0.343506, fy=0.267166, fz=-0.259537
=============================
fx=-0.343506, fy=0.259537, fz=-0.259537

# %%
Start
I2C Open...
FINISHED SETUP, READING GYRO...
=============================
fx=-0.328232, fy=0.244263, fz=-0.267166
=============================
fx=-0.335876, fy=0.251907, fz=-0.236633
=============================
fx=-0.343506, fy=0.267166, fz=-0.259537
=============================
fx=-0.328232, fy=0.274796, fz=-0.259537
=============================
fx=-0.335876, fy=0.259537, fz=-0.251907
=============================
fx=-0.335876, fy=0.259537, fz=-0.251907
=============================
fx=-0.335876, fy=0.267166, fz=-0.282440
=============================
fx=-0.343506, fy=0.274796, fz=-0.259537
=============================
fx=-0.328232, fy=0.251907, fz=-0.251907
=============================
fx=-0.343506, fy=0.274796, fz=-0.274796
=============================
fx=-0.335876, fy=0.267166, fz=-0.274796
=============================
fx=-0.358765, fy=0.274796, fz=-0.244263
=============================
fx=-0.343506, fy=0.290070, fz=-0.251907
=============================
fx=-0.335876, fy=0.267166, fz=-0.251907
=============================
fx=-0.335876, fy=0.274796, fz=-0.251907
=============================
fx=-0.328232, fy=0.274796, fz=-0.251907
=============================
fx=-0.320602, fy=0.267166, fz=-0.267166
=============================
fx=-0.335876, fy=0.267166, fz=-0.251907
=============================
fx=-0.343506, fy=0.267166, fz=-0.244263
=============================
fx=-0.335876, fy=0.267166, fz=-0.274796
=============================
fx=-0.328232, fy=0.267166, fz=-0.282440
=============================
fx=-0.328232, fy=0.259537, fz=-0.251907
=============================
fx=-0.335876, fy=0.251907, fz=-0.259537
=============================
fx=-0.335876, fy=0.290070, fz=-0.259537
=============================
fx=-0.335876, fy=0.259537, fz=-0.267166
=============================
fx=-0.335876, fy=0.251907, fz=-0.259537
=============================
fx=-0.328232, fy=0.274796, fz=-0.282440

# %%
a = test_motor_init()
# Out:
# Starting Motors init...
# 1
# 2
# 3
# 4
# 5
# 6
# PCA init done...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [9], in <cell line: 1>()
# ----> 1 a = test_motor_init()
#
# File /usr/local/share/pynq-venv/lib/python3.10/site-packages/pynq/lib/pynqmicroblaze/magic.py:25, in _FunctionWrapper.__call__(self, *args)
#      24 def __call__(self, *args):
# ---> 25     return self._function(*args)
#
# File <string>:3, in call(self)
#
# File /usr/local/share/pynq-venv/lib/python3.10/site-packages/pynq/lib/pynqmicroblaze/rpc.py:883, in MicroblazeFunction.call(self, *args)
#     881 done = False
#     882 while not done:
# --> 883     return_value, done = self._handle_stream(*args)
#     885 if self.return_type:
#     886     return self.return_type(return_value)
#
# ...

# %%
b = test_motor_start()
# Out:
# motor started with speed : 1050

# %%
c = test_motor_stop()
# Out:
# motor stopped with speed : 0
